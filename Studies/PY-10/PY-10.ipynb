# %% [markdown]
# Модуль PY-10: введение в Pandas.

# %% [markdown]
# Задание 2.4
#
# В аптеку поступают партии лекарств. Их названия находятся в списке names, количество единиц товара находится в списке counts.
#
# Например:
#
# names = ['chlorhexidine', 'cyntomycin', 'afobazol'] counts = [15, 18, 7]
#
# Напишите функцию create_medications(names, counts), которая создает Series medications, индексами которой являются названия лекарств names, а значениями - их количество в поставке counts.
#
# А также напишите функцию get_percent(medications, name), которая возвращает долю количества товара с именем name от общего количества товаров в поставке в процентах.
#
# Примечание. Не забудьте ипортировать библиотеки.
#
# Пример:
# names=['chlorhexidine', 'cyntomycin', 'afobazol']
# counts=[15, 18, 7]
# medications = create_medications(names, counts)
#
# print(get_percent(medications, "chlorhexidine")) #37.5

# %%
import pandas as pd

names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]

def create_medications(names, counts):
    return pd.Series(data=counts, index=names)

medications = create_medications(names, counts)

def get_percent(medications, name):
    return (int(medications[name])/sum(medications))*100

display(medications)
display(get_percent(medications, "chlorhexidine"))
# Out:
# chlorhexidine    15
# cyntomycin       18
# afobazol          7
# dtype: int64
# 37.5

# %% [markdown]
# Задание 3.5
#
# Вы работаете аналитиком в компании ScienceYou. Ваша задача — проанализировать чистую прибыль.
#
# Доходы (income), расходы (expenses) и годы (years), соответствующие им, предоставлены вам в виде списков.
#
# Например:
#
#
# income = [478, 512, 196]
# expenses = [156, 130, 270]
# years = [2018, 2019, 2020]
#
# Создайте функцию create_companyDF(income, expenses, years), которая возвращает DataFrame, составленный из входных данных со столбцами Income и Expenses и индексами, соответствующими годам рассматриваемого периода.
#
# Пример такого DataFrame представлен ниже.
#
#
#     Income  Expenses
# 2018    478     156
# 2019    512     130
# 2020    196     270
#
# Также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанными в таблице df, за год year.
#
# Примечание. Если информация за запрашиваемый год не указана в вашей таблице, вам необходимо вернуть None.

# %%
income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]

def create_companyDF(income, expenses, years):
    return pd.DataFrame({'income':income, 'expenses':expenses}, index=years)

df = create_companyDF(income, expenses, years)

def get_profit(df, year):
    if year in df.index:
        return df.loc[[year], 'income'] - df.loc[[year], 'expenses']
    else:
        return None

display(df)
display(get_profit(df, 208))
# Out:
#       income  expenses
# 2018     478       156
# 2019     512       130
# 2020     196       270
# None

# %%
# Примеры в уроке
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
display(round(int(melb_data.loc[[3521], 'Landsize']) / (melb_data.loc[[1690], 'Landsize'])))

melb_data.tail(7)
melb_data.shape
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
#Задания 6.1-6.9

data = pd.DataFrame([[0,1], [1, 0], [1, 1]], columns=['А', 'B'])
print(data.shape)
type(melb_data['Coordinates'])
display(melb_data.describe().loc[:, ['Price', 'Distance', 'BuildingArea']])
melb_data['Coordinates'].value_counts()
display(melb_data.describe(include=object))
display(melb_data['Type'].value_counts(normalize=True))

# Задания 7.1-7.8
count = 0
display(melb_data['Regionname'].value_counts())
median = melb_data['BuildingArea'].median()
mean = melb_data['BuildingArea'].mean()
round((mean - median)/mean*100)
melb_data['Bedroom'].mode()
melb_data[(melb_data['Bathroom'] <= 0)].shape[0]
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0]
melb_data[melb_data['BuildingArea'] == 0]['Price'].min()
display(round(melb_data[(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015))]['Price'].mean()))
melb_data[(melb_data['Price'] < 3000000) & (melb_data['Type'] == 'h')]['Regionname'].mode()
# Out:
# (3, 2)
#               Price      Distance  BuildingArea
# count  1.358000e+04  13580.000000  13580.000000
# mean   1.075684e+06     10.137776    139.633972
# std    6.393107e+05      5.868725    392.217403
# min    8.500000e+04      0.000000      0.000000
# 25%    6.500000e+05      6.100000    122.000000
# 50%    9.030000e+05      9.200000    126.000000
# 75%    1.330000e+06     13.000000    129.940000
# max    9.000000e+06     48.100000  44515.000000
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# ...

# %%
#Закрепление знаний

students_perfomance_data = pd.read_csv('data/students_performance.csv')
display(students_perfomance_data)
print('Размерность документа:', students_perfomance_data.shape)
print('Баллов у студента под индексом 155 по письму:', students_perfomance_data.loc[155, 'writing score'])
display(students_perfomance_data.info())
print('Средний балл студентов по математике:', round(students_perfomance_data['math score'].mean()))
print('Самая распространённая группа в учебном заведении:', students_perfomance_data['race/ethnicity'].mode())
print('Средний балл студентов по чтению, посещавших подготовительные курсы:',
      round(students_perfomance_data[(students_perfomance_data['test preparation course'] == 'completed')]['reading score'].mean()))
print('Количество студентов, получивших 0 за экзамен по математике:', 
      students_perfomance_data[(students_perfomance_data['math score'] == 0)].shape[0])

mean_free_lunch = round(students_perfomance_data[students_perfomance_data['lunch'] == 'free/reduced']['math score'].mean())
mean_standard_lunch = round(students_perfomance_data[students_perfomance_data['lunch'] == 'standard']['math score'].mean())
print('Разность в средних значениях экзаменов по математике студентов с платным обедом и льготным:', mean_standard_lunch-mean_free_lunch)
print('Средний балл за экзамен по математике у студентов с льготным обедом:', mean_free_lunch)
print('Средний балл за экзамен по математике у студентов с платным обедом:', mean_standard_lunch)
print('Уровни образования студентов в процентных соотнощениях:', students_perfomance_data['parental level of education'].value_counts(normalize=True)*100)
median_math_groupA = students_perfomance_data[(students_perfomance_data['race/ethnicity'] == 'group A')]['writing score'].median()
mean_math_groupC = students_perfomance_data[(students_perfomance_data['race/ethnicity'] == 'group C')]['writing score'].mean()
print('Медианный балл по письму у студентов в расовой группе А отличается от среднего балла по письму у студентов в расовой группе C отличается на:',
      round(abs(median_math_groupA - mean_math_groupC)))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
