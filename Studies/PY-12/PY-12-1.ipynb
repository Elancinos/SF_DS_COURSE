# %% [markdown]
# Ноутбук к модулю PY-12.

# %%
#Импортируем нужные библиотеки
import pandas as pd
import numpy as np

# %%
#Читаем файл (Изменённый, но не собственный)

melb_df = pd.read_csv('data/melb_data_fe.csv')
display(melb_df.head())
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
#Повторяем преобразования данных datetime и category

#копия на всякий случай
melb_df_copy = melb_df.copy()

melb_df_copy['Date'] = pd.to_datetime(melb_df_copy['Date'])
print('Число сделок во втором по популярности квартале -', melb_df_copy['Date'].dt.quarter.value_counts().values[1])
# def category_transformation(table):
#     exclude_list = (['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'])
#     for column in table.columns:
#         if column not in exclude_list and len(table[column].unique()) < 150:
#             table[column] = table[column].astype('category')

for column in melb_df_copy.columns:
    exclude_list = (['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'])
    if column not in exclude_list and len(melb_df_copy[column].unique()) < 150:
        melb_df_copy[column] = melb_df_copy[column].astype('category')
        
display(melb_df_copy.info()) #category(10)
# Out:
# Число сделок во втором по популярности квартале - 4359
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
# ...

# %% [markdown]
#  2. Сортировка данных в DataFrame

# %%
display(melb_df_copy.sort_values(by='Price').head())
display(melb_df_copy.sort_values(by='Date', ascending=False).head())
display(melb_df_copy.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']])
mask1 = melb_df_copy['AreaRatio'] < -0.8
mask2 = melb_df_copy['Type'] == 'townhouse'
mask3 = melb_df_copy['SellerG'] == 'McGrath'
display(melb_df_copy[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']])
#Задания 2.2-2.3
display(melb_df_copy.sort_values(by='AreaRatio', ascending=False, ignore_index=True).loc[1558, ['BuildingArea']])
mask1 = melb_df_copy['Type'] == 'townhouse'
mask2 = melb_df_copy['Rooms'] > 2
display(melb_df_copy[mask1 & mask2].sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True).loc[18, ['Price']])
# Out:
#          Suburb  Rooms   Type     Price Method  SellerG       Date  Distance  \
# 2652  Footscray      1   unit   85000.0     PI  Burnham 2016-03-09       6.4
# 1805      other      4  house  131000.0     PI    other 2017-02-25       8.9
# 7303     Albion      1   unit  145000.0     PI   Biggin 2016-05-28      13.9
# 1927     Coburg      4  house  145000.0     PI   Jellis 2016-04-06       7.8
# 7940   Hawthorn      1   unit  160000.0     VB      HAR 2017-08-04       4.6
#
#       Postcode  Bedroom  ...  Longtitude             Regionname  \
# 2652      3011        1  ...    144.8900   Western Metropolitan
# 1805      3162        4  ...    145.0242  Southern Metropolitan
# 7303      3020        2  ...    144.8266   Western Metropolitan
# 1927      3058        3  ...    144.9658  Northern Metropolitan
# 7940      3122        1  ...    145.0373  Southern Metropolitan
#
#       Propertycount  MeanRoomsSquare AreaRatio  MonthSale  AgeBuilding  \
# ...

# %% [markdown]
# 3. Группировка данных в DataFrame

# %%
display(melb_df_copy.groupby(by='Type').mean(numeric_only=True))
display(melb_df_copy.groupby('Type')['Price'].mean())
display(melb_df_copy.groupby('Regionname')['Distance'].min().sort_values(ascending=False))
display(melb_df_copy.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False))
display(melb_df_copy.groupby('MonthSale')['Price'].agg('describe'))
display(melb_df_copy.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]))

#задания 3.1-3.3
#1
display(melb_df_copy.groupby('Rooms')['Price'].mean().sort_values( ascending=False)) #7
#2
display(melb_df_copy.groupby('Regionname')['Lattitude'].std().sort_values()) #Western Victoria
#3
mask1 = melb_df_copy['Date'] >= pd.to_datetime('2017-05-01')
mask2 = melb_df_copy['Date'] <= pd.to_datetime('2017-09-01')
display(melb_df_copy[mask1 & mask2].groupby('SellerG')['Price'].agg('sum').sort_values()) #LITTLE
# Out:
# C:\Users\Elancinos\AppData\Local\Temp\ipykernel_284\585839472.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   display(melb_df_copy.groupby(by='Type').mean(numeric_only=True))
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# ...

# %% [markdown]
# 4. Сводные таблицы

# %%
display(melb_df_copy.groupby(['Rooms', 'Type'])['Price'].mean())
display(melb_df_copy.groupby(['Rooms', 'Type'])['Price'].mean().unstack())
display(melb_df_copy.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round())
display(melb_df_copy.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
))
display(melb_df_copy.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
))
display(melb_df_copy.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
))
pivot = melb_df_copy.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
display(pivot.columns)
display(pivot['mean']['unit'])
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
#Самостоятельное создание мультииндексной таблицы
mser = pd.Series(
    np.random.rand(8),
	index=[['white','white','white','blue','blue','red','red','red'], 
           ['up','down','right','up','down','up','down','left']])
display(mser)
print(mser.index)
#И датафрейм:
mframe = pd.DataFrame(
    np.random.randn(16).reshape(4,4),
    index=[['white','white','red','red'], ['up','down','up','down']],
    columns=[['pen','pen','paper','paper'],[1,2,1,2]]
)
display(mframe)
# Out:
# C:\Users\Elancinos\AppData\Local\Temp\ipykernel_284\1176234880.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   display(melb_df_copy.groupby(['Rooms', 'Type'])['Price'].mean())
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
# ...
