# %% [markdown]
# # <center> MATH&ML-15. Рекомендательные системы. Часть II

# %%
#Импорты

import pandas as pd
import numpy as np
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

from surprise import Dataset
from surprise import Reader
from surprise.dataset import BUILTIN_DATASETS #с помощью данного объекта мы можем использовать встроенные датасеты
from surprise.model_selection import train_test_split
from surprise import SVD, KNNBasic, accuracy

import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Flatten, Dot, Dense, Concatenate
from tensorflow.keras.models import Model

# %% [markdown]
# ### Юнит 2. Content-based model

# %%
netflix_titles = pd.read_csv('data/netflix_titles.zip')
netflix_titles
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#                                                 country          date_added  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %%
netflix_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
#Обучаем модель TF-IDF
model = TfidfVectorizer(stop_words='english')

netflix_titles['description'] = netflix_titles['description'].fillna('')
feature_matrix = model.fit_transform(netflix_titles['description'])

feature_matrix.shape
# Out:
# (7787, 17905)

# %%
#Вычсляем косинусную близость
cosine_sim = linear_kernel(feature_matrix, feature_matrix)
#В итоге у нас матрица. Вернем для удобства ей индексы
indices = pd.Series(netflix_titles.index,index=netflix_titles['title']).drop_duplicates()

# %%
#Функция для создания рекомендаций
def get_recommendations(title):
    idx = indices[title]
    #вычисляем попарные коэффициенты косинусной близости
    scores = list(enumerate(cosine_sim[idx]))
    #сортируем фильмы на основании коэффициентов косинусной близости по убыванию
    scores = sorted(scores, key=lambda x: x[1], reverse=True)
    #выбираем десять наибольших значений косинусной близости; нулевую не берём, т. к. это тот же фильм
    scores =   scores[1:11]
    #забираем индексы
    ind_movie = [i[0] for i in scores]
    #возвращаем названия по индексам
    return netflix_titles['title'].iloc[ind_movie]

get_recommendations('Star Trek')
# Out:
# 5788             Star Trek: The Next Generation
# 5787                      Star Trek: Enterprise
# 5786                 Star Trek: Deep Space Nine
# 5557                     She's Out of My League
# 134                                  7 Days Out
# 6664                        The Midnight Gospel
# 6023                                     Teresa
# 4863    Pinkfong & Baby Shark's Space Adventure
# 5104                                       Rats
# 5970                             Tales by Light
# Name: title, dtype: object

# %%
#Задание 2.3
get_recommendations('Balto')
# Out:
# 709                Balto 2: Wolf Quest
# 7446                           Vroomiz
# 1338    Chilling Adventures of Sabrina
# 7388                          Vampires
# 1770                          Dinotrux
# 2767                     Hold the Dark
# 5540                 Shanghai Fortress
# 4041                             Mercy
# 2582                       Half & Half
# 1365        Christmas in the Heartland
# Name: title, dtype: object

# %% [markdown]
# ### Юнит 3. Коллаборативная фильтрация

# %%
data = Dataset.load_from_file(
    "data/u.data.txt",
    reader=Reader(line_format="user item rating timestamp", sep="\t"),
)

df = pd.DataFrame(data.raw_ratings, columns=['userId', 'movieId', 'rating', 'timestamp'])
display(df)
# Out:
#       userId movieId  rating  timestamp
# 0        196     242     3.0  881250949
# 1        186     302     3.0  891717742
# 2         22     377     1.0  878887116
# 3        244      51     2.0  880606923
# 4        166     346     1.0  886397596
# ...      ...     ...     ...        ...
# 99995    880     476     3.0  880175444
# 99996    716     204     5.0  879795543
# 99997    276    1090     1.0  874795795
# 99998     13     225     2.0  882399156
# 99999     12     203     3.0  879959583
#
# [100000 rows x 4 columns]

# %% [markdown]
# userId — идентификаторы пользователей сайта movielens;
# movieId — идентификаторы фильмов;
# rating — оценки фильмов, выставленные пользователями по шкале от 1 до 5;
# timestamp — время оценки фильма пользователем. Данный формат представления времени показывает, сколько секунд прошло с 1 января 1970 года.

# %%
#Задание 3.1
print('Всего фильмов в выборке:', len(df['movieId'].value_counts()))
# Out:
# Всего фильмов в выборке: 1682

# %%
#Задание 3.2
print('Всего пользователей в выборке:', len(df['userId'].value_counts()))
# Out:
# Всего пользователей в выборке: 943

# %%
#Задание 3.3
print('Топ оценок:')
display(df['rating'].value_counts())
# Out:
# Топ оценок:
# rating
# 4.0    34174
# 3.0    27145
# 5.0    21201
# 2.0    11370
# 1.0     6110
# Name: count, dtype: int64

# %%
#Задание 3.4

#Судя по документации, принимаются только изначальные данные, не датафрейм
train_df, test_df = train_test_split(data, test_size=0.25, random_state=13)
display(test_df[:3])
print('Количество объектов в тестовой выборке:', len(test_df))
# Out:
# [('7', '633', 5.0), ('422', '287', 3.0), ('804', '163', 3.0)]
# Количество объектов в тестовой выборке: 25000

# %%
#Базовая коллаборативная фильтрация item-based

sim_options = {
    'name': 'cosine',
    'user_based': False
}
 
knn = KNNBasic(sim_options=sim_options)
knn.fit(train_df)

predictions = knn.test(test_df)
display(predictions)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Prediction(uid='7', iid='633', r_ui=5.0, est=4.199452349030111, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='422', iid='287', r_ui=3.0, est=3.4703437660463736, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='804', iid='163', r_ui=3.0, est=3.5716736533692854, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='189', iid='480', r_ui=5.0, est=4.222825780855538, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='238', iid='546', r_ui=3.0, est=3.473417286928204, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='804', iid='216', r_ui=4.0, est=3.922551907749182, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='350', iid='204', r_ui=4.0, est=4.345238219480267, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='708', iid='993', r_ui=4.0, est=3.4458505791534115, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='193', iid='1078', r_ui=4.0, est=3.07510784413058, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='847', iid='173', r_ui=5.0, est=3.300050806141639, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='662', r_ui=3.0, est=3.69830156454333, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='592', iid='1014', r_ui=4.0, est=3.1998176170082737, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6', iid='15', r_ui=3.0, est=3.5999047772513957, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='49', iid='96', r_ui=1.0, est=2.5980114864164348, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='354', iid='1194', r_ui=4.0, est=4.000860894050235, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='265', iid='117', r_ui=5.0, est=3.6386166652345158, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='233', iid='193', r_ui=4.0, est=4.248645101202358, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='345', iid='620', r_ui=2.0, est=3.724835738485935, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='923', iid='831', r_ui=4.0, est=4.3507502906437745, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='833', iid='1143', r_ui=4.0, est=3.125, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='588', iid='443', r_ui=3.0, est=3.8752933806110414, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='50', r_ui=5.0, est=3.6249832673946663, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='334', iid='1525', r_ui=4.0, est=3.5279866666666666, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='909', iid='292', r_ui=4.0, est=4.195752007172238, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='697', iid='713', r_ui=5.0, est=3.6692382055805806, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='370', iid='525', r_ui=4.0, est=3.848874864003559, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='89', r_ui=3.0, est=3.747211938837685, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='458', iid='116', r_ui=4.0, est=3.847791002778979, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='1495', r_ui=3.0, est=3.825, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='921', iid='410', r_ui=2.0, est=3.522332289528116, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='97', iid='670', r_ui=5.0, est=4.127392635709689, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='286', iid='288', r_ui=5.0, est=3.95314051595336, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='257', iid='198', r_ui=3.0, est=3.9514883739447724, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='175', iid='132', r_ui=3.0, est=3.7593017450745414, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='315', iid='187', r_ui=4.0, est=4.201669841153457, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='543', iid='761', r_ui=2.0, est=3.4762386698025205, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='905', iid='245', r_ui=3.0, est=3.2263977703040645, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='313', iid='231', r_ui=2.0, est=3.848215167980456, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='365', iid='908', r_ui=3.0, est=3.331756540843533, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='399', iid='470', r_ui=4.0, est=2.9250880134132413, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='578', iid='272', r_ui=2.0, est=2.71298393127952, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='775', iid='315', r_ui=5.0, est=3.6850338209825795, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='653', iid='200', r_ui=4.0, est=2.673263692490889, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='1572', r_ui=1.0, est=3.5279866666666666, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='498', iid='175', r_ui=5.0, est=3.5723269528257338, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='279', iid='1113', r_ui=3.0, est=3.3, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='76', iid='23', r_ui=5.0, est=4.100699321302352, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='344', iid='708', r_ui=4.0, est=4.125846250290898, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='276', iid='1478', r_ui=3.0, est=2.9, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='267', iid='1090', r_ui=3.0, est=3.6937562478848935, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='497', r_ui=4.0, est=3.1432169160607564, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='1480', r_ui=1.0, est=3.45, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='276', iid='428', r_ui=4.0, est=2.9457911408402135, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='540', iid='762', r_ui=4.0, est=3.7857323261429294, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='399', iid='288', r_ui=3.0, est=2.974343535440141, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='268', iid='250', r_ui=4.0, est=2.872019361176961, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='349', iid='471', r_ui=3.0, est=3.223475938022671, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='854', iid='117', r_ui=3.0, est=3.049479500971992, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='182', iid='845', r_ui=3.0, est=3.832196547515011, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='773', iid='1071', r_ui=2.0, est=3.3241031746593053, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='883', iid='487', r_ui=5.0, est=4.1499382915889305, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='425', iid='258', r_ui=2.0, est=3.274726800443655, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='298', iid='473', r_ui=3.0, est=4.200941748841276, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='114', iid='269', r_ui=4.0, est=3.4898887470944633, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='521', iid='268', r_ui=5.0, est=3.224593331510733, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='346', iid='318', r_ui=5.0, est=3.5263123221873887, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='752', iid='355', r_ui=2.0, est=3.269754952886165, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='509', r_ui=4.0, est=3.6971683818161134, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='716', iid='117', r_ui=4.0, est=3.746935220328798, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='269', iid='5', r_ui=2.0, est=2.950320873765803, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='184', iid='69', r_ui=3.0, est=3.850438530980304, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='174', iid='575', r_ui=1.0, est=3.949993340751277, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='53', r_ui=3.0, est=3.845946445437602, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='200', iid='2', r_ui=4.0, est=3.969269117509676, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='426', iid='1204', r_ui=4.0, est=3.898214990000964, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13', iid='846', r_ui=2.0, est=2.975, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='661', iid='210', r_ui=5.0, est=4.101076838404325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='639', iid='1195', r_ui=2.0, est=2.774165883681317, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='128', iid='133', r_ui=5.0, est=3.7252374907969927, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='357', iid='546', r_ui=5.0, est=4.3013676749715515, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='564', iid='272', r_ui=3.0, est=3.475431713690478, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='758', iid='576', r_ui=4.0, est=3.8250503450057005, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='598', iid='259', r_ui=3.0, est=3.6399239215702583, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='210', iid='483', r_ui=5.0, est=4.274525611249623, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='144', iid='960', r_ui=2.0, est=3.5237869129508383, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='364', iid='319', r_ui=3.0, est=3.502243633122377, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='380', iid='300', r_ui=3.0, est=3.272494402550429, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='749', iid='188', r_ui=3.0, est=3.7968423133733746, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='435', iid='3', r_ui=3.0, est=3.0479215704166798, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='290', r_ui=3.0, est=3.751096294574518, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='548', iid='603', r_ui=5.0, est=3.90131216151074, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='720', r_ui=1.0, est=1.125, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='176', iid='240', r_ui=4.0, est=3.7283315360968654, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='430', r_ui=4.0, est=3.624003593073203, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16', iid='942', r_ui=4.0, est=4.224351870264815, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='70', iid='197', r_ui=4.0, est=3.577051759042252, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='940', iid='354', r_ui=5.0, est=3.5974293928226984, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='551', iid='366', r_ui=5.0, est=3.598840640104643, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='920', iid='300', r_ui=3.0, est=3.2271412280919045, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='130', iid='210', r_ui=5.0, est=3.919803393881592, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7', iid='608', r_ui=4.0, est=3.5000384941332343, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='886', iid='1324', r_ui=2.0, est=3.7, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='880', iid='316', r_ui=5.0, est=3.099665682198066, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='1142', r_ui=2.0, est=3.0, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='385', iid='506', r_ui=2.0, est=3.576343722717137, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='313', iid='237', r_ui=2.0, est=3.9975377537966628, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='32', iid='288', r_ui=4.0, est=3.357707473118339, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='76', iid='547', r_ui=2.0, est=3.6773192373026555, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='892', iid='515', r_ui=5.0, est=4.27227303433439, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='823', iid='66', r_ui=4.0, est=3.975837931550042, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='300', r_ui=4.0, est=3.923445827849886, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='318', iid='205', r_ui=3.0, est=3.895812749763578, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='485', r_ui=5.0, est=3.5701949925706566, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='827', r_ui=4.0, est=3.225, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='412', iid='684', r_ui=4.0, est=3.97479328105175, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='682', iid='196', r_ui=5.0, est=3.1487576094562315, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='110', iid='1090', r_ui=2.0, est=2.9652747281489646, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='521', iid='755', r_ui=3.0, est=3.1495714190554036, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='861', iid='289', r_ui=5.0, est=4.0023624606025505, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='712', iid='584', r_ui=4.0, est=3.7769348505190643, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='568', iid='923', r_ui=3.0, est=3.474591763949734, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='921', iid='15', r_ui=4.0, est=3.522627563319372, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='815', iid='494', r_ui=5.0, est=3.872031113707181, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='523', iid='549', r_ui=4.0, est=4.599500524822178, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='846', iid='566', r_ui=5.0, est=3.6435284955065748, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='184', iid='165', r_ui=4.0, est=3.847668026771911, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='556', iid='513', r_ui=4.0, est=4.325581740127155, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='378', iid='13', r_ui=3.0, est=3.4703365222357974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='870', iid='690', r_ui=2.0, est=3.197054210085647, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='534', iid='628', r_ui=5.0, est=4.023988500116665, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='851', iid='192', r_ui=4.0, est=3.0936405088067542, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='445', iid='310', r_ui=1.0, est=2.023999789020754, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='380', iid='62', r_ui=1.0, est=3.349110709281696, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='26', iid='50', r_ui=4.0, est=3.4023175201951346, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='319', iid='338', r_ui=2.0, est=3.7933553301564515, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='97', iid='82', r_ui=4.0, est=4.175752153986282, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='618', iid='117', r_ui=5.0, est=3.172604034933685, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='217', r_ui=2.0, est=3.7209288574788393, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='913', iid='317', r_ui=4.0, est=3.823827985080838, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='919', iid='174', r_ui=4.0, est=3.722132615970615, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='870', iid='715', r_ui=3.0, est=3.549282626191216, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='415', r_ui=2.0, est=1.275, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='217', iid='144', r_ui=4.0, est=2.8265100699991748, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='109', iid='845', r_ui=4.0, est=3.450564177475175, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='409', r_ui=5.0, est=3.448138251256887, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='818', r_ui=3.0, est=3.6000675346592343, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='340', iid='174', r_ui=4.0, est=4.200098782599134, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='790', iid='403', r_ui=4.0, est=3.2240817579444427, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='282', iid='307', r_ui=3.0, est=3.3819175371731385, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='586', iid='164', r_ui=2.0, est=3.3247826517651244, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='130', iid='2', r_ui=4.0, est=3.64457684420459, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='506', iid='198', r_ui=2.0, est=3.7489483807318433, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='943', iid='210', r_ui=4.0, est=3.5018811286238667, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='363', iid='39', r_ui=4.0, est=2.925162482239632, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='94', iid='1226', r_ui=4.0, est=3.175, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='389', iid='238', r_ui=5.0, est=4.32380790563759, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='624', iid='979', r_ui=4.0, est=3.5744019371633273, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='860', iid='865', r_ui=4.0, est=3.3437331329785542, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='908', iid='144', r_ui=4.0, est=3.6744422794797713, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='122', iid='46', r_ui=5.0, est=3.931042915309801, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='48', iid='680', r_ui=3.0, est=3.8572507372442146, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='805', iid='141', r_ui=2.0, est=3.72514671914643, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='347', iid='157', r_ui=5.0, est=3.6457388951455187, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='520', iid='100', r_ui=4.0, est=3.08802721111001, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='234', iid='436', r_ui=3.0, est=3.1490744707045906, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='397', iid='134', r_ui=5.0, est=4.218938768920796, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='1014', r_ui=3.0, est=3.0707925271861347, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='210', iid='722', r_ui=4.0, est=4.199228005411683, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='158', iid='277', r_ui=4.0, est=3.848793656194784, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='549', r_ui=3.0, est=3.322916325836501, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='790', iid='145', r_ui=2.0, est=2.570450323990713, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='724', iid='877', r_ui=1.0, est=2.1106622112989317, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='234', iid='451', r_ui=3.0, est=3.126035551592862, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='250', iid='44', r_ui=4.0, est=3.750653712810691, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='94', iid='412', r_ui=2.0, est=3.8267223704381728, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='25', iid='495', r_ui=4.0, est=4.075614967665048, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='421', iid='175', r_ui=2.0, est=3.7719411453305676, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='429', iid='768', r_ui=3.0, est=3.373308694195406, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='536', iid='163', r_ui=5.0, est=4.249806930122042, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='115', iid='969', r_ui=1.0, est=3.826434971683506, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='339', iid='508', r_ui=4.0, est=4.045455113814387, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='357', r_ui=5.0, est=3.8961193004452674, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='608', iid='507', r_ui=3.0, est=3.7516095580196267, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='712', iid='232', r_ui=3.0, est=3.826290436655384, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='883', iid='198', r_ui=5.0, est=4.200906422160898, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='603', iid='173', r_ui=4.0, est=3.8929337846632595, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='225', iid='603', r_ui=5.0, est=4.405766770893796, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='655', iid='218', r_ui=3.0, est=2.8251328127391786, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='643', iid='162', r_ui=3.0, est=3.897944054368157, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='479', r_ui=5.0, est=3.1691678011509947, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='56', r_ui=5.0, est=3.3712597913379643, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='428', iid='268', r_ui=4.0, est=3.95489541620263, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='189', iid='7', r_ui=3.0, est=4.173786382935981, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='409', iid='45', r_ui=4.0, est=3.3733987243462393, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='245', iid='133', r_ui=2.0, est=3.3109079315961516, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='41', iid='28', r_ui=4.0, est=3.6677268612134633, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='541', iid='810', r_ui=3.0, est=3.843530828553799, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='846', iid='1209', r_ui=1.0, est=3.65, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='49', iid='1018', r_ui=2.0, est=2.4254074812796165, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='410', iid='352', r_ui=3.0, est=3.2003215950213804, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='234', iid='216', r_ui=3.0, est=3.423960509543575, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='130', iid='331', r_ui=3.0, est=3.6498438946404463, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='363', iid='222', r_ui=5.0, est=3.1715706154772527, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='435', iid='930', r_ui=3.0, est=3.2977078232798265, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='1119', r_ui=5.0, est=3.7738737570422987, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='839', iid='950', r_ui=4.0, est=3.3169838243151806, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid='320', iid='472', r_ui=3.0, est=3.772926839990355, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='305', iid='190', r_ui=3.0, est=3.3978544062033147, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='293', iid='632', r_ui=3.0, est=2.547397296678621, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='457', iid='443', r_ui=4.0, est=4.375034053144597, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='261', iid='259', r_ui=4.0, est=4.04417056734998, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='658', iid='168', r_ui=3.0, est=3.773637735276123, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='684', iid='742', r_ui=4.0, est=3.624641331538051, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='532', iid='501', r_ui=5.0, est=4.14714969928115, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='545', iid='326', r_ui=3.0, est=3.4745413036328974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='498', iid='174', r_ui=3.0, est=3.274367765692108, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='158', iid='433', r_ui=3.0, est=4.322871504557923, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18', iid='216', r_ui=4.0, est=4.023387170641003, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='393', iid='1435', r_ui=3.0, est=3.325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='813', iid='9', r_ui=3.0, est=2.8516208408753365, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='585', iid='1319', r_ui=2.0, est=3.5636335284965797, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='158', iid='502', r_ui=4.0, est=3.8503671910012494, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='259', iid='357', r_ui=5.0, est=3.8937652369449043, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='160', iid='273', r_ui=5.0, est=4.175200562322735, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='567', iid='192', r_ui=4.0, est=4.0502829282349495, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62', iid='283', r_ui=4.0, est=3.4992963247664988, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='204', r_ui=3.0, est=3.475420933673526, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='738', iid='528', r_ui=4.0, est=3.8499255666471366, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='23', iid='541', r_ui=4.0, est=3.847496699340866, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='643', iid='50', r_ui=4.0, est=4.1503486291463805, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='437', iid='692', r_ui=4.0, est=3.8745494671338236, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1', iid='117', r_ui=3.0, est=3.7691407511738264, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='559', iid='194', r_ui=3.0, est=3.798652917506532, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='805', iid='431', r_ui=1.0, est=3.2977897330139543, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='248', iid='96', r_ui=4.0, est=3.5754451404315586, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='195', r_ui=4.0, est=3.6437554855263796, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='886', iid='49', r_ui=4.0, est=3.320961959127114, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='323', iid='744', r_ui=5.0, est=3.8728529184274367, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='368', iid='777', r_ui=2.0, est=3.08, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='796', iid='684', r_ui=5.0, est=3.7485337318033567, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='624', iid='845', r_ui=3.0, est=3.6262947930059166, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='492', iid='242', r_ui=5.0, est=3.580170227945, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='932', iid='498', r_ui=5.0, est=4.247972718944143, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='1199', r_ui=3.0, est=2.95, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='796', iid='217', r_ui=4.0, est=3.3985083828496405, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='915', iid='302', r_ui=4.0, est=3.153988680261241, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='318', iid='768', r_ui=2.0, est=3.721786514656055, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='454', iid='1190', r_ui=3.0, est=2.7, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='268', iid='217', r_ui=2.0, est=2.3264785528864573, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='864', iid='736', r_ui=5.0, est=3.595694327691956, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='417', iid='827', r_ui=2.0, est=3.199390498816688, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='918', iid='86', r_ui=4.0, est=3.550346845000696, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='753', iid='64', r_ui=4.0, est=3.6058737078589727, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='406', iid='150', r_ui=4.0, est=3.4999360711308847, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='308', iid='169', r_ui=5.0, est=3.6993892517234572, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='650', iid='212', r_ui=3.0, est=3.3227904101062595, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='221', iid='1016', r_ui=3.0, est=3.873982818863081, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='160', iid='56', r_ui=5.0, est=4.300875616786216, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='815', r_ui=4.0, est=3.52526039201736, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='554', iid='13', r_ui=2.0, est=3.674135411960293, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='94', iid='173', r_ui=4.0, est=4.097193227009217, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='218', r_ui=3.0, est=3.3989034492339387, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='933', iid='180', r_ui=5.0, est=3.1948852584798604, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='149', iid='321', r_ui=2.0, est=2.7705087979496117, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='396', iid='245', r_ui=3.0, est=3.236446743317234, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='935', iid='405', r_ui=4.0, est=3.8487448296611486, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='212', iid='382', r_ui=5.0, est=3.9959419143594013, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='666', iid='288', r_ui=3.0, est=3.4245692361766054, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='125', iid='427', r_ui=4.0, est=3.4976052332860306, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='321', iid='513', r_ui=4.0, est=3.7249889799452203, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='305', iid='655', r_ui=4.0, est=3.800259811893002, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='269', iid='1101', r_ui=4.0, est=3.293503684330507, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='654', iid='476', r_ui=3.0, est=3.95002867995374, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='193', iid='682', r_ui=1.0, est=3.353776242359449, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='419', iid='306', r_ui=5.0, est=4.291030001432043, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='113', iid='742', r_ui=3.0, est=3.6911537827097685, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='634', iid='1048', r_ui=3.0, est=3.3243363541997337, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='911', iid='530', r_ui=4.0, est=3.8013475213088412, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='322', r_ui=4.0, est=3.5261984586233828, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='871', iid='346', r_ui=3.0, est=3.3742009365555607, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='275', iid='1', r_ui=4.0, est=3.2515392047925116, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='770', iid='294', r_ui=3.0, est=4.3516974063552185, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='221', iid='1067', r_ui=3.0, est=3.6962997746543413, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='162', iid='230', r_ui=2.0, est=3.6721940534397612, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='489', iid='897', r_ui=2.0, est=3.7, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='95', iid='181', r_ui=4.0, est=3.6496155376423594, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='273', iid='319', r_ui=4.0, est=3.6249166735910006, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='843', iid='627', r_ui=2.0, est=2.6500752386057473, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='763', iid='111', r_ui=2.0, est=3.8236282690289616, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='659', iid='134', r_ui=4.0, est=4.125850113145709, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='707', iid='770', r_ui=3.0, est=3.548926351265751, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='792', iid='844', r_ui=4.0, est=3.1353767342097614, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='134', iid='294', r_ui=4.0, est=3.508317589738033, details={'actual_k': 18, 'was_impossible': False}),
#  Prediction(uid='622', iid='1203', r_ui=3.0, est=3.2213424558257846, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='892', iid='401', r_ui=3.0, est=3.977743758945368, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='822', iid='432', r_ui=3.0, est=3.19069506831486, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='521', iid='159', r_ui=3.0, est=3.0988464410838206, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='661', iid='427', r_ui=4.0, est=3.9776752575437255, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='542', iid='427', r_ui=5.0, est=3.7759767019673216, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='25', iid='177', r_ui=3.0, est=4.07617589697998, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='886', iid='11', r_ui=5.0, est=3.473699318843036, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='394', iid='795', r_ui=2.0, est=3.446705057824819, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='90', iid='904', r_ui=3.0, est=3.95, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='320', iid='292', r_ui=3.0, est=3.696074493116822, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='614', iid='293', r_ui=3.0, est=3.2587470716781293, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='372', iid='561', r_ui=5.0, est=4.346486397906752, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='712', iid='365', r_ui=3.0, est=3.847998642842222, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='170', iid='245', r_ui=5.0, est=3.745889068149622, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='592', iid='194', r_ui=4.0, est=3.7956588146674193, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='639', r_ui=5.0, est=3.549800203666289, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='431', iid='286', r_ui=4.0, est=3.5432392172577716, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='334', iid='129', r_ui=4.0, est=3.623400772827543, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='670', iid='96', r_ui=5.0, est=3.8287867922745518, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='790', iid='1044', r_ui=4.0, est=2.9456362133839495, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='889', iid='128', r_ui=5.0, est=3.4248990351365927, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='796', iid='143', r_ui=5.0, est=3.54748714459343, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='543', iid='462', r_ui=4.0, est=3.6715125330892877, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='586', r_ui=3.0, est=3.10058951581209, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='503', iid='97', r_ui=4.0, est=3.996704790926658, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='73', iid='382', r_ui=4.0, est=4.124771144225842, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='342', iid='813', r_ui=5.0, est=3.224834813940376, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='311', iid='131', r_ui=3.0, est=3.674628581411899, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7', iid='594', r_ui=3.0, est=4.1, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='64', r_ui=5.0, est=3.994873982496101, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='398', iid='523', r_ui=4.0, est=3.874605326565389, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='458', iid='190', r_ui=4.0, est=3.7959520922301437, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='246', iid='101', r_ui=2.0, est=2.8248933521213706, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='694', iid='434', r_ui=5.0, est=4.122624477518385, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid='942', r_ui=3.0, est=2.5244748585285874, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='160', iid='234', r_ui=5.0, est=4.350048231635669, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='160', iid='603', r_ui=4.0, est=4.200736210829845, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='440', iid='886', r_ui=5.0, est=4.133634119347755, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='716', iid='234', r_ui=5.0, est=4.049876726581625, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='270', iid='443', r_ui=3.0, est=4.575239634566744, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='389', iid='210', r_ui=2.0, est=3.9762369643463167, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='506', iid='746', r_ui=5.0, est=3.7254061186473204, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='279', iid='654', r_ui=5.0, est=2.798726754501, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='282', r_ui=3.0, est=3.7260795131734974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='510', r_ui=4.0, est=3.8222810433145704, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='346', iid='642', r_ui=3.0, est=3.3203074685718437, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='199', iid='323', r_ui=3.0, est=2.9548589941758068, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='286', iid='95', r_ui=5.0, est=3.9013217244806753, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='472', iid='418', r_ui=3.0, est=4.124001027312186, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='561', r_ui=3.0, est=2.9771921488610382, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='331', iid='1141', r_ui=3.0, est=3.5276515352345035, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='270', iid='156', r_ui=5.0, est=4.400568376054925, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='705', iid='566', r_ui=4.0, est=3.7004159241708003, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='782', iid='331', r_ui=3.0, est=2.498982492503207, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='117', iid='405', r_ui=5.0, est=4.325870466030751, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='843', iid='101', r_ui=3.0, est=2.6238702336463517, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='459', iid='1060', r_ui=1.0, est=3.399544406447897, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='752', iid='327', r_ui=5.0, est=3.202479762490777, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='710', iid='258', r_ui=2.0, est=3.87583764848897, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='861', iid='463', r_ui=3.0, est=4.001121605058195, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='276', iid='332', r_ui=4.0, est=3.024649374610215, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='618', iid='144', r_ui=4.0, est=3.44915355431835, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='151', iid='461', r_ui=4.0, est=3.9732987309229437, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='844', iid='1474', r_ui=4.0, est=3.57294886139354, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='308', iid='69', r_ui=2.0, est=3.54870296147903, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='548', iid='275', r_ui=3.0, est=3.848631269102389, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='287', iid='252', r_ui=1.0, est=4.1287628905889875, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56', iid='399', r_ui=4.0, est=3.8958125391118674, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='109', iid='1210', r_ui=3.0, est=3.394010676420569, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='943', iid='217', r_ui=3.0, est=3.4501776196310234, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='535', iid='942', r_ui=4.0, est=3.95026417449889, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='536', iid='164', r_ui=4.0, est=4.148897085518855, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43', iid='684', r_ui=4.0, est=4.224568036079402, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='497', iid='403', r_ui=3.0, est=3.699842212826497, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='739', r_ui=4.0, est=3.570532293046511, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13', iid='138', r_ui=1.0, est=2.875, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='233', iid='47', r_ui=5.0, est=4.201496522891478, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='104', iid='984', r_ui=1.0, est=2.5132330468882778, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='249', iid='478', r_ui=4.0, est=4.224422722074541, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='593', iid='51', r_ui=3.0, est=3.493310028737632, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='455', iid='258', r_ui=5.0, est=3.750340403910224, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='741', iid='781', r_ui=4.0, est=3.627083682224399, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='686', iid='1184', r_ui=1.0, est=4.728809724366255, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='441', iid='121', r_ui=4.0, est=3.3167824206388046, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='566', iid='202', r_ui=4.0, est=3.552556185684407, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='388', r_ui=3.0, est=3.625, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='182', iid='150', r_ui=3.0, est=3.825156210184093, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='407', iid='747', r_ui=3.0, est=3.748364727821407, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44', iid='591', r_ui=4.0, est=3.723777146485196, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='840', iid='423', r_ui=5.0, est=3.9986957352010766, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='452', iid='1109', r_ui=2.0, est=3.498920406753839, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='560', iid='606', r_ui=4.0, est=3.5000224332102765, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='506', iid='550', r_ui=4.0, est=3.6991003487736442, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='409', iid='1242', r_ui=2.0, est=3.925, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='202', r_ui=4.0, est=3.968386483269809, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='907', iid='619', r_ui=2.0, est=4.723410545663497, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='370', iid='210', r_ui=3.0, est=3.901036461609002, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='881', iid='443', r_ui=5.0, est=3.595591722200151, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='844', iid='117', r_ui=4.0, est=3.6246101158398614, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='875', iid='651', r_ui=5.0, est=4.248931448235451, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='201', iid='1220', r_ui=2.0, est=2.7496952059383504, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='152', iid='549', r_ui=4.0, est=4.451001618090182, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='659', iid='712', r_ui=3.0, est=3.6743115286930284, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='930', iid='756', r_ui=3.0, est=3.098733861149136, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='9', r_ui=1.0, est=3.520149879631244, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='108', iid='121', r_ui=3.0, est=3.6053056077849197, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='532', iid='367', r_ui=5.0, est=4.019451662117112, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='738', iid='50', r_ui=5.0, est=4.1012799955126225, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid='923', r_ui=3.0, est=2.2989809178311114, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='73', iid='202', r_ui=2.0, est=4.075961219885551, details={'actual_k': 40, 'was_impossible': False}),
# ...
#  Prediction(uid='943', iid='233', r_ui=5.0, est=3.47642170371463, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='65', iid='211', r_ui=4.0, est=4.000064808813512, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='524', iid='1041', r_ui=2.0, est=3.224218060542789, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='1225', r_ui=2.0, est=3.3495490443109053, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='854', iid='423', r_ui=4.0, est=3.624738352211172, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='343', iid='77', r_ui=3.0, est=3.8491845431783607, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='313', iid='488', r_ui=5.0, est=3.8216408655584586, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13', iid='540', r_ui=3.0, est=2.475, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='911', iid='474', r_ui=5.0, est=3.848826032442246, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='554', iid='209', r_ui=4.0, est=3.700785682336644, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='277', iid='129', r_ui=4.0, est=3.5911660596688972, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='908', iid='701', r_ui=4.0, est=3.7008115331078226, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='625', iid='519', r_ui=2.0, est=3.5257629825582377, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='712', iid='215', r_ui=3.0, est=4.000243309853349, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='181', iid='934', r_ui=3.0, est=1.225, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='622', iid='1231', r_ui=2.0, est=3.1510272721133004, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='324', iid='748', r_ui=5.0, est=4.2502908753466055, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='263', iid='1126', r_ui=5.0, est=4.093822733286973, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='639', iid='70', r_ui=3.0, est=3.1514693172174923, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='398', iid='159', r_ui=3.0, est=3.8712093343038934, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='286', iid='56', r_ui=2.0, est=4.027845239997604, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='486', iid='1302', r_ui=3.0, est=3.1, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='556', iid='187', r_ui=5.0, est=4.3452280797069855, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='280', iid='217', r_ui=3.0, est=3.729223848940788, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='807', iid='373', r_ui=4.0, est=3.799130320000983, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='883', iid='271', r_ui=2.0, est=3.850862571348953, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62', iid='147', r_ui=3.0, est=3.2011372149074124, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='523', iid='1036', r_ui=4.0, est=4.580314361859272, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='748', iid='144', r_ui=4.0, est=3.825988513090031, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='927', iid='385', r_ui=4.0, est=4.1231138117498, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='50', iid='1008', r_ui=5.0, est=3.537774706773962, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='128', iid='485', r_ui=3.0, est=3.8246133537930893, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='299', iid='345', r_ui=4.0, est=3.324120290282335, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='551', iid='1419', r_ui=1.0, est=3.55, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='144', iid='262', r_ui=3.0, est=3.897685234271868, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='483', r_ui=5.0, est=3.5994844721399204, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='189', iid='647', r_ui=4.0, est=3.9249608818013466, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='326', iid='657', r_ui=5.0, est=3.425005108172141, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='647', iid='1047', r_ui=4.0, est=3.8754546287621747, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='406', iid='1197', r_ui=3.0, est=3.55008830468919, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='533', iid='580', r_ui=3.0, est=3.1742753531498655, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='378', iid='265', r_ui=4.0, est=3.3721537867750837, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='693', iid='1232', r_ui=2.0, est=2.9271210050467817, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='327', iid='546', r_ui=2.0, est=3.5015791942227397, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='258', r_ui=5.0, est=3.9223569369039284, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='897', iid='176', r_ui=5.0, est=4.100421534106072, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='269', iid='168', r_ui=4.0, est=3.6242314174305053, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='821', iid='495', r_ui=5.0, est=4.353275407032272, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='295', iid='50', r_ui=5.0, est=4.324102549488621, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='904', iid='66', r_ui=4.0, est=3.89025770438799, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='437', iid='378', r_ui=4.0, est=3.622795049950825, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='751', iid='742', r_ui=3.0, est=3.3744829637685534, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='442', iid='172', r_ui=5.0, est=3.52536255241196, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='542', iid='772', r_ui=4.0, est=3.4190120367506984, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='847', iid='567', r_ui=3.0, est=2.7291768690700065, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44', iid='24', r_ui=3.0, est=3.7991878491952527, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='425', iid='27', r_ui=3.0, est=2.7991351465060217, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='668', iid='333', r_ui=3.0, est=3.5059689372051333, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='581', iid='222', r_ui=3.0, est=3.9505589320663237, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='666', iid='651', r_ui=5.0, est=3.849798717819351, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='593', iid='742', r_ui=4.0, est=3.82407096966054, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='423', iid='1134', r_ui=4.0, est=3.660353433553939, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='790', iid='72', r_ui=2.0, est=2.922700680811602, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='896', iid='58', r_ui=3.0, est=3.1455440731937325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='288', iid='528', r_ui=4.0, est=3.8473853617911424, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='14', iid='81', r_ui=5.0, est=4.146964316271125, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='454', iid='493', r_ui=2.0, est=2.799975177800182, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='605', iid='252', r_ui=4.0, est=3.8521971130844816, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='468', iid='612', r_ui=4.0, est=3.897829693059612, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='805', iid='99', r_ui=2.0, est=3.6746200056797487, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='512', iid='183', r_ui=5.0, est=4.245150375598059, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='33', iid='245', r_ui=3.0, est=3.7071618785774247, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='401', iid='151', r_ui=1.0, est=3.5749179330271517, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='818', iid='271', r_ui=4.0, est=3.5275865274504086, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='550', iid='300', r_ui=4.0, est=3.3104737937662723, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='270', iid='123', r_ui=5.0, est=4.395607928213477, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='644', iid='117', r_ui=4.0, est=4.100649475272147, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='453', iid='515', r_ui=4.0, est=3.544763865233498, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='210', iid='180', r_ui=4.0, est=4.175583036463767, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='247', iid='70', r_ui=5.0, est=3.8932666024628197, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='500', iid='699', r_ui=3.0, est=3.4747900407148165, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='909', iid='261', r_ui=5.0, est=4.1288910249787545, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='595', iid='460', r_ui=4.0, est=3.620681933228555, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='804', iid='1285', r_ui=2.0, est=3.425, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='899', iid='403', r_ui=3.0, est=3.8029377219785108, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='368', iid='670', r_ui=3.0, est=3.2210955611336, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='201', iid='226', r_ui=3.0, est=3.076543377570166, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='606', iid='64', r_ui=5.0, est=3.9975358813521065, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='246', iid='121', r_ui=4.0, est=2.5973710042229294, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='298', r_ui=1.0, est=3.119237461116429, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='751', iid='746', r_ui=4.0, est=3.6257903987226623, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='99', r_ui=2.0, est=3.7015827018723155, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='393', iid='1185', r_ui=3.0, est=3.325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='861', iid='737', r_ui=3.0, est=4.011122042109093, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='593', iid='553', r_ui=2.0, est=3.495583859426324, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='487', iid='823', r_ui=1.0, est=3.8000272291464996, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='697', iid='596', r_ui=4.0, est=3.7799965454377418, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='1470', r_ui=2.0, est=2.225, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='151', iid='49', r_ui=3.0, est=4.197798176676655, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='387', iid='972', r_ui=2.0, est=3.474679954936728, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='889', iid='199', r_ui=5.0, est=3.297432024845269, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='106', iid='956', r_ui=3.0, est=3.873172644884685, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='495', iid='413', r_ui=5.0, est=4.12377860480974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='896', iid='184', r_ui=3.0, est=2.971813778793501, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='314', iid='1218', r_ui=4.0, est=3.97374671516261, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='1110', r_ui=1.0, est=2.8997809828485313, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='551', iid='118', r_ui=5.0, est=3.5936530662158357, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='495', iid='768', r_ui=3.0, est=3.922634705452259, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='624', iid='405', r_ui=4.0, est=3.8247000413341548, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='474', iid='275', r_ui=3.0, est=3.9736634280244094, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='417', iid='325', r_ui=2.0, est=2.9980581094112706, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='654', iid='736', r_ui=5.0, est=3.7516351108899, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='336', iid='451', r_ui=2.0, est=3.2225460816784435, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='417', iid='5', r_ui=4.0, est=3.2455269080167124, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='418', r_ui=3.0, est=2.9496536638962167, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='699', iid='304', r_ui=4.0, est=3.1745029664049857, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='26', iid='283', r_ui=3.0, est=3.2504925147412753, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='941', iid='358', r_ui=2.0, est=4.365041886722779, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='653', iid='101', r_ui=3.0, est=2.7745825657597325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='608', iid='136', r_ui=3.0, est=3.825341304151815, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='710', iid='346', r_ui=4.0, est=3.826620714550039, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='390', iid='328', r_ui=4.0, est=3.830408983238243, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='316', iid='735', r_ui=4.0, est=3.9261845216065643, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='796', iid='182', r_ui=4.0, est=3.499992634920175, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='327', iid='678', r_ui=3.0, est=3.3268608118787912, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='197', iid='11', r_ui=1.0, est=3.825552174585011, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='275', iid='679', r_ui=3.0, est=3.1754661520168335, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='102', iid='778', r_ui=3.0, est=2.674169816267397, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='715', iid='53', r_ui=1.0, est=3.54623876345051, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='334', iid='483', r_ui=5.0, est=3.8236983552310186, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62', iid='196', r_ui=4.0, est=3.4746580639126226, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='601', iid='699', r_ui=3.0, est=3.298270899207589, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='595', r_ui=3.0, est=2.7253160305389383, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='250', iid='596', r_ui=5.0, est=4.024960560154663, details={'actual_k': 40, 'was_impossible': False}),
#  ...]

# %%
#Для предсказания какого-то определенного объекта необходимо помнить, 
# что все данные, кроме реального рейтинга представленные в виде object

#Задание 3.5
display(df[(df['userId']=='500') & (df['movieId']=='699')])
pred = knn.predict(uid='500', iid='699', r_ui=3)
pred
# Out:
#       userId movieId  rating  timestamp
# 34367    500     699     3.0  883875523
# Prediction(uid='500', iid='699', r_ui=3, est=3.4747900407148165, details={'actual_k': 40, 'was_impossible': False})

# %%
print(accuracy.rmse(predictions))

pred = pd.DataFrame(predictions)
pred.sort_values(by=['est'],inplace=True,ascending = False)

#Пример вывода рекомендаций
recom = pred[pred.uid =='849']['iid'].to_list()
print('movieId для данного пользователя:', recom)
# Out:
# RMSE: 1.0272
# 1.0271678039029761
# movieId для данного пользователя: ['234', '427', '568', '174']

# %%
#Задание 3.6
#Базовая коллаборативная фильтрация user-based

sim_options = {
    'name': 'cosine',
    'user_based': True
}
 
knn = KNNBasic(sim_options=sim_options)
knn.fit(train_df)

predictions = knn.test(test_df)
display(predictions)

print(accuracy.rmse(predictions))

pred = pd.DataFrame(predictions)
pred.sort_values(by=['est'],inplace=True,ascending = False)

#Пример вывода рекомендаций
recom = pred[pred.uid =='849']['iid'].to_list()
print('movieId для данного пользователя:', recom)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# [Prediction(uid='7', iid='633', r_ui=5.0, est=4.150997362033697, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='422', iid='287', r_ui=3.0, est=3.754016750770759, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='804', iid='163', r_ui=3.0, est=3.70096140390557, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='189', iid='480', r_ui=5.0, est=4.524549229206855, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='238', iid='546', r_ui=3.0, est=3.1991812561559425, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='804', iid='216', r_ui=4.0, est=3.9500160918588327, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='350', iid='204', r_ui=4.0, est=4.1983705425936275, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='708', iid='993', r_ui=4.0, est=3.6795202365264075, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='193', iid='1078', r_ui=4.0, est=2.9339965985927674, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid='847', iid='173', r_ui=5.0, est=4.022693009990196, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='662', r_ui=3.0, est=3.500869100820158, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='592', iid='1014', r_ui=4.0, est=3.0974120429419885, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='6', iid='15', r_ui=3.0, est=3.7508327982430623, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='49', iid='96', r_ui=1.0, est=3.6018635028131674, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='354', iid='1194', r_ui=4.0, est=3.983818521538349, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid='265', iid='117', r_ui=5.0, est=3.7490027148165126, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='233', iid='193', r_ui=4.0, est=4.175519022063219, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='345', iid='620', r_ui=2.0, est=3.104672286323065, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='923', iid='831', r_ui=4.0, est=2.5782291572254334, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='833', iid='1143', r_ui=4.0, est=3.7161673665349197, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='588', iid='443', r_ui=3.0, est=3.7516173525285765, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='50', r_ui=5.0, est=4.299574058567666, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='334', iid='1525', r_ui=4.0, est=3.5279866666666666, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='909', iid='292', r_ui=4.0, est=3.8500384929079328, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='697', iid='713', r_ui=5.0, est=3.67601962092916, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='370', iid='525', r_ui=4.0, est=3.9742308355665386, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='89', r_ui=3.0, est=4.325680921673537, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='458', iid='116', r_ui=4.0, est=3.82914499525774, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='1495', r_ui=3.0, est=4.006233728415884, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='921', iid='410', r_ui=2.0, est=3.1717155485730624, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='97', iid='670', r_ui=5.0, est=2.9490016703752886, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='286', iid='288', r_ui=5.0, est=3.449997486060894, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='257', iid='198', r_ui=3.0, est=4.175480149407038, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='175', iid='132', r_ui=3.0, est=4.223687970793381, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='315', iid='187', r_ui=4.0, est=4.325818563514485, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='543', iid='761', r_ui=2.0, est=3.072606403813491, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='905', iid='245', r_ui=3.0, est=3.2991985682118714, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='313', iid='231', r_ui=2.0, est=2.900569629259917, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='365', iid='908', r_ui=3.0, est=2.553441114985336, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='399', iid='470', r_ui=4.0, est=3.9489904996898484, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='578', iid='272', r_ui=2.0, est=4.222759614167509, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='775', iid='315', r_ui=5.0, est=4.023657074433422, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='653', iid='200', r_ui=4.0, est=3.824349660884802, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='1572', r_ui=1.0, est=3.5279866666666666, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='498', iid='175', r_ui=5.0, est=4.125289299464548, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='279', iid='1113', r_ui=3.0, est=3.4295840542606735, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='76', iid='23', r_ui=5.0, est=4.473889619236572, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='344', iid='708', r_ui=4.0, est=3.8259284541767933, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='276', iid='1478', r_ui=3.0, est=2.636809024934436, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='267', iid='1090', r_ui=3.0, est=2.381317210168144, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='648', iid='497', r_ui=4.0, est=4.001728746569709, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='1480', r_ui=1.0, est=2.595708663796823, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='276', iid='428', r_ui=4.0, est=3.975729971992761, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='540', iid='762', r_ui=4.0, est=3.350167927252739, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='288', r_ui=3.0, est=3.473586877912615, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='268', iid='250', r_ui=4.0, est=3.5252957826943434, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='349', iid='471', r_ui=3.0, est=3.749930168435368, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='854', iid='117', r_ui=3.0, est=3.5501162048057, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='182', iid='845', r_ui=3.0, est=3.724000765248034, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='773', iid='1071', r_ui=2.0, est=3.000311289005261, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='883', iid='487', r_ui=5.0, est=4.178656833875824, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='425', iid='258', r_ui=2.0, est=3.7761930195586664, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='298', iid='473', r_ui=3.0, est=3.224337463788413, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='114', iid='269', r_ui=4.0, est=4.12516135560975, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='521', iid='268', r_ui=5.0, est=3.573839650337831, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='346', iid='318', r_ui=5.0, est=4.675852979474668, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='752', iid='355', r_ui=2.0, est=3.0008014643640304, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='916', iid='509', r_ui=4.0, est=4.050776933552907, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='716', iid='117', r_ui=4.0, est=3.7496109197062317, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='269', iid='5', r_ui=2.0, est=3.1681015722610466, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='184', iid='69', r_ui=3.0, est=4.0748354555042186, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='174', iid='575', r_ui=1.0, est=2.7240658365391055, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='244', iid='53', r_ui=3.0, est=3.351626965390484, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='200', iid='2', r_ui=4.0, est=3.60068337882099, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='426', iid='1204', r_ui=4.0, est=3.5967645502930736, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='13', iid='846', r_ui=2.0, est=3.200093217025632, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='661', iid='210', r_ui=5.0, est=4.175455887522344, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='639', iid='1195', r_ui=2.0, est=3.2782349062651575, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='128', iid='133', r_ui=5.0, est=4.074861672393828, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='357', iid='546', r_ui=5.0, est=3.0733659489289713, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='564', iid='272', r_ui=3.0, est=4.125120616348251, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='758', iid='576', r_ui=4.0, est=3.148232610287651, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='598', iid='259', r_ui=3.0, est=2.5267721142033355, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='210', iid='483', r_ui=5.0, est=4.67451590771948, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='144', iid='960', r_ui=2.0, est=3.3057272400431814, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='364', iid='319', r_ui=3.0, est=3.5752078615744285, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='380', iid='300', r_ui=3.0, est=3.925704567261694, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='749', iid='188', r_ui=3.0, est=3.775132791160332, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='435', iid='3', r_ui=3.0, est=3.150050329796449, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='290', r_ui=3.0, est=2.949942017836543, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='548', iid='603', r_ui=5.0, est=4.451200465793417, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='720', r_ui=1.0, est=3.279966715696525, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='176', iid='240', r_ui=4.0, est=2.8471260559301306, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='430', r_ui=4.0, est=4.1761643300518445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='16', iid='942', r_ui=4.0, est=3.4746941406593383, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='70', iid='197', r_ui=4.0, est=4.524850802940544, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='940', iid='354', r_ui=5.0, est=3.454384139658859, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='551', iid='366', r_ui=5.0, est=3.3851883638480054, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='920', iid='300', r_ui=3.0, est=3.675, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='130', iid='210', r_ui=5.0, est=4.100300125116222, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7', iid='608', r_ui=4.0, est=3.9565394010164385, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='886', iid='1324', r_ui=2.0, est=2.0305211953161737, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='880', iid='316', r_ui=5.0, est=4.226381904659445, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='1142', r_ui=2.0, est=4.097743660097214, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid='385', iid='506', r_ui=2.0, est=4.127540725950772, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='313', iid='237', r_ui=2.0, est=3.775036717459822, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='32', iid='288', r_ui=4.0, est=3.325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='76', iid='547', r_ui=2.0, est=3.4132853536713434, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='892', iid='515', r_ui=5.0, est=4.500441547986847, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='823', iid='66', r_ui=4.0, est=3.424532975280713, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='300', r_ui=4.0, est=3.8500748711663255, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='318', iid='205', r_ui=3.0, est=4.098946690752753, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='485', r_ui=5.0, est=3.9997853556674294, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='416', iid='827', r_ui=4.0, est=2.677508315858009, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='412', iid='684', r_ui=4.0, est=3.8753166882652916, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='682', iid='196', r_ui=5.0, est=3.9748935085806627, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='110', iid='1090', r_ui=2.0, est=2.394312687384787, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='521', iid='755', r_ui=3.0, est=3.45087422628672, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='861', iid='289', r_ui=5.0, est=3.3502058234409495, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='712', iid='584', r_ui=4.0, est=3.800212293692794, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='568', iid='923', r_ui=3.0, est=4.286049255482425, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='921', iid='15', r_ui=4.0, est=4.150294334631083, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='815', iid='494', r_ui=5.0, est=3.974264044768718, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='523', iid='549', r_ui=4.0, est=3.699759494432286, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='846', iid='566', r_ui=5.0, est=3.725365630587963, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='184', iid='165', r_ui=4.0, est=4.10269683662743, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='556', iid='513', r_ui=4.0, est=4.425507870921279, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='378', iid='13', r_ui=3.0, est=3.551834346983737, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='870', iid='690', r_ui=2.0, est=3.201491654513782, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='534', iid='628', r_ui=5.0, est=3.54957710354734, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='851', iid='192', r_ui=4.0, est=4.075293825875276, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='445', iid='310', r_ui=1.0, est=3.7224110956257777, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='380', iid='62', r_ui=1.0, est=3.302234447188489, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='26', iid='50', r_ui=4.0, est=4.297928262428739, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='319', iid='338', r_ui=2.0, est=2.600172996762817, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='97', iid='82', r_ui=4.0, est=3.7744202870624903, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='618', iid='117', r_ui=5.0, est=3.824874158145318, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='217', r_ui=2.0, est=3.5260284472716403, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='913', iid='317', r_ui=4.0, est=3.9751883171258746, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='919', iid='174', r_ui=4.0, est=4.322564320432382, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='870', iid='715', r_ui=3.0, est=3.4261462964073766, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='415', r_ui=2.0, est=2.820039784116202, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='217', iid='144', r_ui=4.0, est=3.6549090942792724, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='109', iid='845', r_ui=4.0, est=3.8235780524248293, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='409', r_ui=5.0, est=3.2320940423609064, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='818', r_ui=3.0, est=2.683056658664641, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='340', iid='174', r_ui=4.0, est=4.274586065770819, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='790', iid='403', r_ui=4.0, est=3.825054721476521, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='282', iid='307', r_ui=3.0, est=3.649368499692392, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='586', iid='164', r_ui=2.0, est=3.8020043385841396, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='130', iid='2', r_ui=4.0, est=3.4505589808948405, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='506', iid='198', r_ui=2.0, est=4.2490169034074246, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='943', iid='210', r_ui=4.0, est=3.9487248835744224, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='363', iid='39', r_ui=4.0, est=3.3021669940427465, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='94', iid='1226', r_ui=4.0, est=3.499629831137126, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='389', iid='238', r_ui=5.0, est=4.249942553385513, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='624', iid='979', r_ui=4.0, est=3.2039367914195074, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='860', iid='865', r_ui=4.0, est=3.601836300764411, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='908', iid='144', r_ui=4.0, est=4.075098877653025, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='122', iid='46', r_ui=5.0, est=3.495101115686034, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='48', iid='680', r_ui=3.0, est=2.780889964860475, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='805', iid='141', r_ui=2.0, est=3.6763135319760547, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='347', iid='157', r_ui=5.0, est=4.050583894047309, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='520', iid='100', r_ui=4.0, est=4.075, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='234', iid='436', r_ui=3.0, est=3.6493034223691057, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='397', iid='134', r_ui=5.0, est=4.549805433471218, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='1014', r_ui=3.0, est=3.149696081982599, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='210', iid='722', r_ui=4.0, est=2.978143570719835, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='158', iid='277', r_ui=4.0, est=3.774683090930883, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='549', r_ui=3.0, est=3.5512300136180635, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='790', iid='145', r_ui=2.0, est=2.72726147026027, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='724', iid='877', r_ui=1.0, est=2.5989457952345276, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='234', iid='451', r_ui=3.0, est=3.7247775119738105, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='250', iid='44', r_ui=4.0, est=3.325255506340952, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='94', iid='412', r_ui=2.0, est=2.503131610690494, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='25', iid='495', r_ui=4.0, est=3.6000190424348415, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='421', iid='175', r_ui=2.0, est=3.647457476188648, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='429', iid='768', r_ui=3.0, est=3.0766105028011697, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='536', iid='163', r_ui=5.0, est=3.5779830309613594, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='115', iid='969', r_ui=1.0, est=3.891756486823581, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='339', iid='508', r_ui=4.0, est=3.82521849654729, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='357', r_ui=5.0, est=4.52517209817048, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='608', iid='507', r_ui=3.0, est=3.9004440913181257, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='712', iid='232', r_ui=3.0, est=3.427639009806458, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='883', iid='198', r_ui=5.0, est=4.200507579080287, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='603', iid='173', r_ui=4.0, est=4.299100617784226, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='225', iid='603', r_ui=5.0, est=4.399594532420802, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='655', iid='218', r_ui=3.0, est=3.700247725619713, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='643', iid='162', r_ui=3.0, est=3.975971088290005, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='479', r_ui=5.0, est=4.424528091019567, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='56', r_ui=5.0, est=4.074006799840254, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='428', iid='268', r_ui=4.0, est=3.7768239956520757, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='189', iid='7', r_ui=3.0, est=4.0997549832074185, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='409', iid='45', r_ui=4.0, est=4.050531357904715, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='245', iid='133', r_ui=2.0, est=3.8998768652681104, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='41', iid='28', r_ui=4.0, est=4.000276551978561, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='541', iid='810', r_ui=3.0, est=2.8149387676517277, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='846', iid='1209', r_ui=1.0, est=2.538915221616402, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='49', iid='1018', r_ui=2.0, est=3.2800891365354015, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='410', iid='352', r_ui=3.0, est=2.020276425843105, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='234', iid='216', r_ui=3.0, est=4.025365931451481, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='130', iid='331', r_ui=3.0, est=3.596786499221486, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='363', iid='222', r_ui=5.0, est=3.724414524197127, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='435', iid='930', r_ui=3.0, est=2.7005592348522103, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='1119', r_ui=5.0, est=3.65166588294112, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='839', iid='950', r_ui=4.0, est=2.7835036271021374, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='320', iid='472', r_ui=3.0, est=3.298370629208991, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='305', iid='190', r_ui=3.0, est=4.27574034057473, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='293', iid='632', r_ui=3.0, est=4.0525279569687145, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='457', iid='443', r_ui=4.0, est=4.000145747750134, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='261', iid='259', r_ui=4.0, est=2.622029799113631, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='658', iid='168', r_ui=3.0, est=4.324783034772237, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='684', iid='742', r_ui=4.0, est=3.8745184640877453, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='532', iid='501', r_ui=5.0, est=3.8006889444053114, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='545', iid='326', r_ui=3.0, est=3.525135994158656, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='498', iid='174', r_ui=3.0, est=4.349660611656458, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='158', iid='433', r_ui=3.0, est=3.947808166596634, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='18', iid='216', r_ui=4.0, est=3.9249378678848004, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='393', iid='1435', r_ui=3.0, est=3.000093266604927, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='813', iid='9', r_ui=3.0, est=3.95, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='585', iid='1319', r_ui=2.0, est=1, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='158', iid='502', r_ui=4.0, est=3.807817120747352, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='259', iid='357', r_ui=5.0, est=4.524473976653235, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='160', iid='273', r_ui=5.0, est=3.7485836562359416, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='567', iid='192', r_ui=4.0, est=4.425804102471524, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62', iid='283', r_ui=4.0, est=3.8243441843608434, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='204', r_ui=3.0, est=3.8749646875478203, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='738', iid='528', r_ui=4.0, est=4.326155449022256, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='23', iid='541', r_ui=4.0, est=2.8437039735069685, details={'actual_k': 38, 'was_impossible': False}),
#  Prediction(uid='643', iid='50', r_ui=4.0, est=4.499585362176192, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='437', iid='692', r_ui=4.0, est=3.751026808942694, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='1', iid='117', r_ui=3.0, est=3.6027587350345365, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='559', iid='194', r_ui=3.0, est=3.9759240832345313, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='805', iid='431', r_ui=1.0, est=3.3484225765486038, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='248', iid='96', r_ui=4.0, est=4.150643607639893, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='222', iid='195', r_ui=4.0, est=4.24948691966024, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='886', iid='49', r_ui=4.0, est=3.251121112721387, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='323', iid='744', r_ui=5.0, est=3.5001472219233163, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='368', iid='777', r_ui=2.0, est=1, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='796', iid='684', r_ui=5.0, est=3.975296999558099, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='624', iid='845', r_ui=3.0, est=3.5769298899496205, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='492', iid='242', r_ui=5.0, est=3.8997166948866058, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='932', iid='498', r_ui=5.0, est=4.375398995110501, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='303', iid='1199', r_ui=3.0, est=2.784971773651042, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='796', iid='217', r_ui=4.0, est=3.6260970960096235, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='915', iid='302', r_ui=4.0, est=4.198697863252672, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='318', iid='768', r_ui=2.0, est=3.082551002347874, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='454', iid='1190', r_ui=3.0, est=3.380797893571317, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='268', iid='217', r_ui=2.0, est=3.3736956312455235, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='864', iid='736', r_ui=5.0, est=3.8987843034357863, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='417', iid='827', r_ui=2.0, est=2.6797530883755534, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='918', iid='86', r_ui=4.0, est=4.174694834624542, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='753', iid='64', r_ui=4.0, est=4.624896701346091, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='406', iid='150', r_ui=4.0, est=3.999142915175968, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='308', iid='169', r_ui=5.0, est=4.550163064244834, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='650', iid='212', r_ui=3.0, est=3.749162148881563, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='221', iid='1016', r_ui=3.0, est=3.625668397330586, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='160', iid='56', r_ui=5.0, est=3.998310885323444, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='815', r_ui=4.0, est=3.071304932519291, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='554', iid='13', r_ui=2.0, est=3.1999635048605404, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='94', iid='173', r_ui=4.0, est=4.274823025403945, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='642', iid='218', r_ui=3.0, est=3.6750246364541175, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='933', iid='180', r_ui=5.0, est=4.2741060978633305, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='149', iid='321', r_ui=2.0, est=3.1003903858726876, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='396', iid='245', r_ui=3.0, est=3.198457450796429, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='935', iid='405', r_ui=4.0, est=3.4771314578487957, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='212', iid='382', r_ui=5.0, est=3.6811537288624323, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='666', iid='288', r_ui=3.0, est=3.4254377810388723, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='125', iid='427', r_ui=4.0, est=4.3242803402796355, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='321', iid='513', r_ui=4.0, est=4.352113101937846, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='305', iid='655', r_ui=4.0, est=3.9770715809428516, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='269', iid='1101', r_ui=4.0, est=3.8740670432456876, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='654', iid='476', r_ui=3.0, est=3.101757832972574, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='193', iid='682', r_ui=1.0, est=3.0507983265451646, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='419', iid='306', r_ui=5.0, est=3.924549745865737, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='113', iid='742', r_ui=3.0, est=3.8487043899369007, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='634', iid='1048', r_ui=3.0, est=3.120886609939802, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='911', iid='530', r_ui=4.0, est=4.15286041638154, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='322', r_ui=4.0, est=3.0723632025593948, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='871', iid='346', r_ui=3.0, est=3.625781690141066, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='275', iid='1', r_ui=4.0, est=3.8998488721552964, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='770', iid='294', r_ui=3.0, est=3.1238477536248435, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='221', iid='1067', r_ui=3.0, est=3.4434097541805366, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='162', iid='230', r_ui=2.0, est=3.8255871713169185, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='489', iid='897', r_ui=2.0, est=1, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='95', iid='181', r_ui=4.0, est=4.224333134210106, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='273', iid='319', r_ui=4.0, est=3.149571676124312, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='843', iid='627', r_ui=2.0, est=3.450395727946559, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='763', iid='111', r_ui=2.0, est=3.6484177879699, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='659', iid='134', r_ui=4.0, est=4.500205516314118, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='707', iid='770', r_ui=3.0, est=3.451721900464877, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='792', iid='844', r_ui=4.0, est=3.405457978024378, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='134', iid='294', r_ui=4.0, est=3.225, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='622', iid='1203', r_ui=3.0, est=3.945020280294374, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='892', iid='401', r_ui=3.0, est=2.9273650172108026, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='822', iid='432', r_ui=3.0, est=4.000322763079804, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='521', iid='159', r_ui=3.0, est=3.4517072024884508, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='661', iid='427', r_ui=4.0, est=4.575106038792218, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='542', iid='427', r_ui=5.0, est=4.550042199248907, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='25', iid='177', r_ui=3.0, est=4.274952529270829, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='886', iid='11', r_ui=5.0, est=3.874561152301982, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='394', iid='795', r_ui=2.0, est=2.5480977348237435, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='90', iid='904', r_ui=3.0, est=3.8140610902567, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='320', iid='292', r_ui=3.0, est=3.7948393156602322, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='614', iid='293', r_ui=3.0, est=3.895424414810689, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='372', iid='561', r_ui=5.0, est=3.102147803403374, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='712', iid='365', r_ui=3.0, est=3.3673746196792407, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='170', iid='245', r_ui=5.0, est=2.9744311249759723, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='592', iid='194', r_ui=4.0, est=4.150518724227533, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='894', iid='639', r_ui=5.0, est=3.9323888399959133, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid='431', iid='286', r_ui=4.0, est=3.65, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='334', iid='129', r_ui=4.0, est=4.050327098623193, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='670', iid='96', r_ui=5.0, est=4.302322390964359, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='790', iid='1044', r_ui=4.0, est=3.163830196749762, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='889', iid='128', r_ui=5.0, est=3.3514497050952037, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='796', iid='143', r_ui=5.0, est=4.221948248445392, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='543', iid='462', r_ui=4.0, est=3.8249314412049733, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='586', r_ui=3.0, est=2.711990848636445, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid='503', iid='97', r_ui=4.0, est=4.025360101362218, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='73', iid='382', r_ui=4.0, est=3.6770752829857747, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='342', iid='813', r_ui=5.0, est=3.88611350262809, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='311', iid='131', r_ui=3.0, est=3.726019941838883, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='7', iid='594', r_ui=3.0, est=2.3312614194885013, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='416', iid='64', r_ui=5.0, est=4.600537154127857, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='398', iid='523', r_ui=4.0, est=4.150308102260041, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='458', iid='190', r_ui=4.0, est=4.374116847231036, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='246', iid='101', r_ui=2.0, est=3.4025511045313057, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='694', iid='434', r_ui=5.0, est=3.8507967345926737, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='537', iid='942', r_ui=3.0, est=3.476834664811254, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='160', iid='234', r_ui=5.0, est=3.849498843788048, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='160', iid='603', r_ui=4.0, est=4.524469513524931, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='440', iid='886', r_ui=5.0, est=3.1542393268930953, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='716', iid='234', r_ui=5.0, est=4.02431159143105, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='270', iid='443', r_ui=3.0, est=4.052475700231772, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='389', iid='210', r_ui=2.0, est=3.9247734602058175, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='506', iid='746', r_ui=5.0, est=3.6732966529800377, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='279', iid='654', r_ui=5.0, est=4.326236893370324, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='282', r_ui=3.0, est=3.673731079660314, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='271', iid='510', r_ui=4.0, est=4.275203430594146, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='346', iid='642', r_ui=3.0, est=3.3258295617566693, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='199', iid='323', r_ui=3.0, est=2.7722264908586935, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='286', iid='95', r_ui=5.0, est=3.9519479717531634, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='472', iid='418', r_ui=3.0, est=3.675026535417252, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='92', iid='561', r_ui=3.0, est=3.202101164013509, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='331', iid='1141', r_ui=3.0, est=3.3280967294586596, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='270', iid='156', r_ui=5.0, est=4.148471467841265, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='705', iid='566', r_ui=4.0, est=3.725629536668959, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='782', iid='331', r_ui=3.0, est=3.5773395612758323, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='117', iid='405', r_ui=5.0, est=3.4002772348137476, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='843', iid='101', r_ui=3.0, est=3.3752222751494774, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='459', iid='1060', r_ui=1.0, est=2.979236727828609, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='752', iid='327', r_ui=5.0, est=3.5752060390959297, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='710', iid='258', r_ui=2.0, est=3.9501181383262955, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='861', iid='463', r_ui=3.0, est=3.8607289948665064, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='276', iid='332', r_ui=4.0, est=3.2743816368022642, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='618', iid='144', r_ui=4.0, est=4.100550616982058, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='151', iid='461', r_ui=4.0, est=3.678285084218633, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='844', iid='1474', r_ui=4.0, est=2.804541548336956, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='308', iid='69', r_ui=2.0, est=3.849344772737123, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='548', iid='275', r_ui=3.0, est=4.073680162380713, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='287', iid='252', r_ui=1.0, est=2.9500834592490333, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='56', iid='399', r_ui=4.0, est=3.4493252245469894, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='109', iid='1210', r_ui=3.0, est=2.679948691997861, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='943', iid='217', r_ui=3.0, est=3.700225633557184, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='535', iid='942', r_ui=4.0, est=3.479942635056077, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='536', iid='164', r_ui=4.0, est=3.976960622698392, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='43', iid='684', r_ui=4.0, est=4.0494224481634, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='497', iid='403', r_ui=3.0, est=3.6499043301552105, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='739', r_ui=4.0, est=3.626019313413505, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13', iid='138', r_ui=1.0, est=2.6230454386603443, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='233', iid='47', r_ui=5.0, est=3.7751056925768065, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='104', iid='984', r_ui=1.0, est=2.9042834868222283, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='249', iid='478', r_ui=4.0, est=4.274577985702521, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='593', iid='51', r_ui=3.0, est=3.473005901246201, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='455', iid='258', r_ui=5.0, est=3.6248120209676165, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='741', iid='781', r_ui=4.0, est=3.4991850665065147, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='686', iid='1184', r_ui=1.0, est=2.9009652853600656, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='441', iid='121', r_ui=4.0, est=3.574946009481353, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='566', iid='202', r_ui=4.0, est=3.500245373768411, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='450', iid='388', r_ui=3.0, est=2.185167737330124, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='182', iid='150', r_ui=3.0, est=3.7230892816350316, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='407', iid='747', r_ui=3.0, est=3.7246120445449593, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='44', iid='591', r_ui=4.0, est=3.6005326190309757, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='840', iid='423', r_ui=5.0, est=3.9504716007893386, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='452', iid='1109', r_ui=2.0, est=3.4478487169462078, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid='560', iid='606', r_ui=4.0, est=4.252675238112377, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='506', iid='550', r_ui=4.0, est=3.6501725949826196, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='409', iid='1242', r_ui=2.0, est=4.493063476215889, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='416', iid='202', r_ui=4.0, est=3.9753990122778706, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='907', iid='619', r_ui=2.0, est=3.279667345295921, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='370', iid='210', r_ui=3.0, est=4.000260191244078, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='881', iid='443', r_ui=5.0, est=4.002340706511108, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='844', iid='117', r_ui=4.0, est=3.751045924867613, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='875', iid='651', r_ui=5.0, est=4.275581537670186, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='201', iid='1220', r_ui=2.0, est=3.5833710575916666, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='152', iid='549', r_ui=4.0, est=3.7283829028747464, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='659', iid='712', r_ui=3.0, est=3.033947892640325, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='930', iid='756', r_ui=3.0, est=3.1498724432499854, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='648', iid='9', r_ui=1.0, est=3.877308040726116, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='108', iid='121', r_ui=3.0, est=3.449405270748902, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='532', iid='367', r_ui=5.0, est=3.5005710350206143, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='738', iid='50', r_ui=5.0, est=4.6243139657846974, details={'actual_k': 40, 'was_impossible': False}),
# ...
#  Prediction(uid='65', iid='211', r_ui=4.0, est=4.274669152176386, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='524', iid='1041', r_ui=2.0, est=3.363040547073651, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='1225', r_ui=2.0, est=2.7183325808107686, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='854', iid='423', r_ui=4.0, est=3.9232892225933553, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='343', iid='77', r_ui=3.0, est=3.2996353706634296, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='313', iid='488', r_ui=5.0, est=4.153931140229398, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='13', iid='540', r_ui=3.0, est=2.5241028827564733, details={'actual_k': 33, 'was_impossible': False}),
#  Prediction(uid='911', iid='474', r_ui=5.0, est=4.274138098576787, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='554', iid='209', r_ui=4.0, est=3.951200665865873, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='277', iid='129', r_ui=4.0, est=3.876586092170285, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='908', iid='701', r_ui=4.0, est=4.002902793768431, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='625', iid='519', r_ui=2.0, est=4.150758163023522, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='712', iid='215', r_ui=3.0, est=4.152105623637057, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='181', iid='934', r_ui=3.0, est=2.95433778281257, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='622', iid='1231', r_ui=2.0, est=2.2572272038887617, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='324', iid='748', r_ui=5.0, est=3.4762602125982114, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='263', iid='1126', r_ui=5.0, est=3.1292339306467607, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='639', iid='70', r_ui=3.0, est=3.9002276084383185, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='398', iid='159', r_ui=3.0, est=3.5252014854016966, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='286', iid='56', r_ui=2.0, est=4.174438095771263, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='486', iid='1302', r_ui=3.0, est=3.7751141101144525, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='556', iid='187', r_ui=5.0, est=4.325265290713616, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='217', r_ui=3.0, est=3.499852780098328, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='807', iid='373', r_ui=4.0, est=2.9743955763825505, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='883', iid='271', r_ui=2.0, est=3.35151399323421, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62', iid='147', r_ui=3.0, est=3.476765639267328, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='523', iid='1036', r_ui=4.0, est=2.7250883904309786, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='748', iid='144', r_ui=4.0, est=3.976072826703357, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='927', iid='385', r_ui=4.0, est=3.676786372691783, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='50', iid='1008', r_ui=5.0, est=3.224753862697976, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid='128', iid='485', r_ui=3.0, est=4.0247350721527955, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='299', iid='345', r_ui=4.0, est=3.4742664962220715, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='551', iid='1419', r_ui=1.0, est=2.2142850962646516, details={'actual_k': 10, 'was_impossible': False}),
#  Prediction(uid='144', iid='262', r_ui=3.0, est=3.777650801256094, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='916', iid='483', r_ui=5.0, est=4.7254267755849515, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='189', iid='647', r_ui=4.0, est=4.172761136749543, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='326', iid='657', r_ui=5.0, est=4.421895817240055, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='647', iid='1047', r_ui=4.0, est=3.0742129817517965, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='406', iid='1197', r_ui=3.0, est=3.581494683898349, details={'actual_k': 36, 'was_impossible': False}),
#  Prediction(uid='533', iid='580', r_ui=3.0, est=3.4146192267851636, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='378', iid='265', r_ui=4.0, est=4.148872370980844, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='693', iid='1232', r_ui=2.0, est=2.3173616178289516, details={'actual_k': 13, 'was_impossible': False}),
#  Prediction(uid='327', iid='546', r_ui=2.0, est=2.9760617931323696, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='244', iid='258', r_ui=5.0, est=3.724988135803749, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='897', iid='176', r_ui=5.0, est=4.174454422650156, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='269', iid='168', r_ui=4.0, est=4.2484675959797285, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='821', iid='495', r_ui=5.0, est=3.5992616239705013, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='295', iid='50', r_ui=5.0, est=4.324718908033714, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='904', iid='66', r_ui=4.0, est=3.5731485087306663, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='437', iid='378', r_ui=4.0, est=4.0236289119093, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='751', iid='742', r_ui=3.0, est=3.474723185727653, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='442', iid='172', r_ui=5.0, est=4.248951272901088, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='542', iid='772', r_ui=4.0, est=3.0659225464560618, details={'actual_k': 34, 'was_impossible': False}),
#  Prediction(uid='847', iid='567', r_ui=3.0, est=2.738557156399406, details={'actual_k': 26, 'was_impossible': False}),
#  Prediction(uid='44', iid='24', r_ui=3.0, est=3.7222265631218963, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='425', iid='27', r_ui=3.0, est=3.110699307164005, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='668', iid='333', r_ui=3.0, est=3.675475721304633, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='581', iid='222', r_ui=3.0, est=3.600107421304151, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='666', iid='651', r_ui=5.0, est=4.075544120962133, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='593', iid='742', r_ui=4.0, est=4.124162592019577, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='423', iid='1134', r_ui=4.0, est=3.3090143102268814, details={'actual_k': 30, 'was_impossible': False}),
#  Prediction(uid='790', iid='72', r_ui=2.0, est=3.376519431019956, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='896', iid='58', r_ui=3.0, est=3.8745141154848404, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='288', iid='528', r_ui=4.0, est=4.351028352808616, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='14', iid='81', r_ui=5.0, est=3.751598725398701, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='454', iid='493', r_ui=2.0, est=4.12558692738111, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='605', iid='252', r_ui=4.0, est=2.8257153377331443, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='468', iid='612', r_ui=4.0, est=3.8436226124869934, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='805', iid='99', r_ui=2.0, est=4.10265306404863, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='512', iid='183', r_ui=5.0, est=3.8496526858026825, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='33', iid='245', r_ui=3.0, est=3.1493409917959174, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='401', iid='151', r_ui=1.0, est=3.876025155330982, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='818', iid='271', r_ui=4.0, est=3.4011298917316974, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='550', iid='300', r_ui=4.0, est=3.3496717304552437, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='270', iid='123', r_ui=5.0, est=3.175068418994198, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='644', iid='117', r_ui=4.0, est=3.6753942500871686, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='453', iid='515', r_ui=4.0, est=4.226228519460869, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='210', iid='180', r_ui=4.0, est=4.223425467158924, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='247', iid='70', r_ui=5.0, est=3.8256210364739887, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='500', iid='699', r_ui=3.0, est=3.874874678028893, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='909', iid='261', r_ui=5.0, est=2.4807214754273903, details={'actual_k': 28, 'was_impossible': False}),
#  Prediction(uid='595', iid='460', r_ui=4.0, est=2.799208120843255, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid='804', iid='1285', r_ui=2.0, est=3.332669774754731, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='899', iid='403', r_ui=3.0, est=3.6499089207652675, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='368', iid='670', r_ui=3.0, est=2.9581252341002133, details={'actual_k': 32, 'was_impossible': False}),
#  Prediction(uid='201', iid='226', r_ui=3.0, est=3.2994743651313554, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='606', iid='64', r_ui=5.0, est=4.624261100088388, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='246', iid='121', r_ui=4.0, est=3.4768429297058043, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='298', r_ui=1.0, est=3.8252657722953045, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='751', iid='746', r_ui=4.0, est=3.7243201822560907, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='280', iid='99', r_ui=2.0, est=3.975681194932634, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='393', iid='1185', r_ui=3.0, est=2.0010279412087275, details={'actual_k': 14, 'was_impossible': False}),
#  Prediction(uid='861', iid='737', r_ui=3.0, est=2.9821484337977813, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='593', iid='553', r_ui=2.0, est=3.5742273892870258, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='487', iid='823', r_ui=1.0, est=2.924711334578996, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='697', iid='596', r_ui=4.0, est=3.3005661220388887, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='405', iid='1470', r_ui=2.0, est=3.019019260539817, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='151', iid='49', r_ui=3.0, est=3.3508559913933196, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='387', iid='972', r_ui=2.0, est=3.2487127910814704, details={'actual_k': 22, 'was_impossible': False}),
#  Prediction(uid='889', iid='199', r_ui=5.0, est=4.324420923360005, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='106', iid='956', r_ui=3.0, est=3.6513568815318704, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='495', iid='413', r_ui=5.0, est=2.5591719202863183, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='896', iid='184', r_ui=3.0, est=3.749834276007198, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='314', iid='1218', r_ui=4.0, est=3.5484326454119035, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='303', iid='1110', r_ui=1.0, est=2.752092683880172, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid='551', iid='118', r_ui=5.0, est=3.1993327351117373, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='495', iid='768', r_ui=3.0, est=3.0805280421982735, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid='624', iid='405', r_ui=4.0, est=3.4007877125129626, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='474', iid='275', r_ui=3.0, est=4.3505060470692545, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='417', iid='325', r_ui=2.0, est=2.720994871315483, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='654', iid='736', r_ui=5.0, est=3.776063786795879, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='336', iid='451', r_ui=2.0, est=3.399637516393608, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='417', iid='5', r_ui=4.0, est=3.5000586540061884, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='399', iid='418', r_ui=3.0, est=3.8268629402703707, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='699', iid='304', r_ui=4.0, est=3.725493199561365, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='26', iid='283', r_ui=3.0, est=3.748530653120502, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='941', iid='358', r_ui=2.0, est=2.3747755622555826, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='653', iid='101', r_ui=3.0, est=3.3754923935253043, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='608', iid='136', r_ui=3.0, est=4.377078442128511, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='710', iid='346', r_ui=4.0, est=3.75042027866476, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='390', iid='328', r_ui=4.0, est=3.5996845101386143, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='316', iid='735', r_ui=4.0, est=4.051068835042034, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='796', iid='182', r_ui=4.0, est=4.049833826664657, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='327', iid='678', r_ui=3.0, est=2.574122012144365, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='197', iid='11', r_ui=1.0, est=3.7478332417328986, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='275', iid='679', r_ui=3.0, est=3.124686240788624, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='102', iid='778', r_ui=3.0, est=3.8017852183303273, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='715', iid='53', r_ui=1.0, est=3.0757513901894744, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='334', iid='483', r_ui=5.0, est=4.700708374909887, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='62', iid='196', r_ui=4.0, est=3.9760558943828563, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='601', iid='699', r_ui=3.0, est=3.649293650610279, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='145', iid='595', r_ui=3.0, est=3.1743016621225952, details={'actual_k': 40, 'was_impossible': False}),
#  Prediction(uid='250', iid='596', r_ui=5.0, est=3.4791961079689053, details={'actual_k': 40, 'was_impossible': False}),
#  ...]
# RMSE: 1.0175
# 1.0174852296380237
# movieId для данного пользователя: ['427', '174', '568', '234']

# %%
knn = SVD()
knn.fit(train_df)

predictions = knn.test(test_df)
display(predictions)

print(accuracy.rmse(predictions))

pred = pd.DataFrame(predictions)
pred.sort_values(by=['est'],inplace=True,ascending = False)

#Пример вывода рекомендаций
recom = pred[pred.uid =='849']['iid'].to_list()
print('movieId для данного пользователя:', recom)
# Out:
# [Prediction(uid='7', iid='633', r_ui=5.0, est=4.64024779258598, details={'was_impossible': False}),
#  Prediction(uid='422', iid='287', r_ui=3.0, est=3.837707787547249, details={'was_impossible': False}),
#  Prediction(uid='804', iid='163', r_ui=3.0, est=3.716589498709493, details={'was_impossible': False}),
#  Prediction(uid='189', iid='480', r_ui=5.0, est=4.590363701128451, details={'was_impossible': False}),
#  Prediction(uid='238', iid='546', r_ui=3.0, est=2.8808099768401343, details={'was_impossible': False}),
#  Prediction(uid='804', iid='216', r_ui=4.0, est=4.315455648482262, details={'was_impossible': False}),
#  Prediction(uid='350', iid='204', r_ui=4.0, est=3.7727455398412943, details={'was_impossible': False}),
#  Prediction(uid='708', iid='993', r_ui=4.0, est=3.6888715264257623, details={'was_impossible': False}),
#  Prediction(uid='193', iid='1078', r_ui=4.0, est=3.0454415500590204, details={'was_impossible': False}),
#  Prediction(uid='847', iid='173', r_ui=5.0, est=3.957082021835286, details={'was_impossible': False}),
#  Prediction(uid='244', iid='662', r_ui=3.0, est=3.2683231694301904, details={'was_impossible': False}),
#  Prediction(uid='592', iid='1014', r_ui=4.0, est=3.1605203067087513, details={'was_impossible': False}),
#  Prediction(uid='6', iid='15', r_ui=3.0, est=3.1660468444885526, details={'was_impossible': False}),
#  Prediction(uid='49', iid='96', r_ui=1.0, est=2.5737910187359927, details={'was_impossible': False}),
#  Prediction(uid='354', iid='1194', r_ui=4.0, est=4.1317476974983895, details={'was_impossible': False}),
#  Prediction(uid='265', iid='117', r_ui=5.0, est=3.9122808824371242, details={'was_impossible': False}),
#  Prediction(uid='233', iid='193', r_ui=4.0, est=4.462921119501933, details={'was_impossible': False}),
#  Prediction(uid='345', iid='620', r_ui=2.0, est=3.5396802842030377, details={'was_impossible': False}),
#  Prediction(uid='923', iid='831', r_ui=4.0, est=3.350381506500584, details={'was_impossible': False}),
#  Prediction(uid='833', iid='1143', r_ui=4.0, est=3.4282580496417627, details={'was_impossible': False}),
#  Prediction(uid='588', iid='443', r_ui=3.0, est=3.871199769127564, details={'was_impossible': False}),
#  Prediction(uid='916', iid='50', r_ui=5.0, est=4.097648346912561, details={'was_impossible': False}),
#  Prediction(uid='334', iid='1525', r_ui=4.0, est=3.364094560673887, details={'was_impossible': False}),
#  Prediction(uid='909', iid='292', r_ui=4.0, est=4.3417644726840905, details={'was_impossible': False}),
#  Prediction(uid='697', iid='713', r_ui=5.0, est=3.923611295396308, details={'was_impossible': False}),
#  Prediction(uid='370', iid='525', r_ui=4.0, est=3.6932295259584134, details={'was_impossible': False}),
#  Prediction(uid='271', iid='89', r_ui=3.0, est=4.306849418317749, details={'was_impossible': False}),
#  Prediction(uid='458', iid='116', r_ui=4.0, est=3.9325425631324835, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1495', r_ui=3.0, est=4.004381127441332, details={'was_impossible': False}),
#  Prediction(uid='921', iid='410', r_ui=2.0, est=2.886028056469837, details={'was_impossible': False}),
#  Prediction(uid='97', iid='670', r_ui=5.0, est=3.1836253836020285, details={'was_impossible': False}),
#  Prediction(uid='286', iid='288', r_ui=5.0, est=3.7026475613354957, details={'was_impossible': False}),
#  Prediction(uid='257', iid='198', r_ui=3.0, est=4.30796927670682, details={'was_impossible': False}),
#  Prediction(uid='175', iid='132', r_ui=3.0, est=4.02096643066895, details={'was_impossible': False}),
#  Prediction(uid='315', iid='187', r_ui=4.0, est=3.939335547862629, details={'was_impossible': False}),
#  Prediction(uid='543', iid='761', r_ui=2.0, est=2.9502325895806623, details={'was_impossible': False}),
#  Prediction(uid='905', iid='245', r_ui=3.0, est=2.6354708957768582, details={'was_impossible': False}),
#  Prediction(uid='313', iid='231', r_ui=2.0, est=2.552990930104338, details={'was_impossible': False}),
#  Prediction(uid='365', iid='908', r_ui=3.0, est=2.5920422036280373, details={'was_impossible': False}),
#  Prediction(uid='399', iid='470', r_ui=4.0, est=3.1172467737851957, details={'was_impossible': False}),
#  Prediction(uid='578', iid='272', r_ui=2.0, est=3.8209556729770813, details={'was_impossible': False}),
#  Prediction(uid='775', iid='315', r_ui=5.0, est=4.014547375477559, details={'was_impossible': False}),
#  Prediction(uid='653', iid='200', r_ui=4.0, est=3.2958808847206744, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1572', r_ui=1.0, est=1.8847982394202887, details={'was_impossible': False}),
#  Prediction(uid='498', iid='175', r_ui=5.0, est=3.4979392854836777, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1113', r_ui=3.0, est=3.4267493895041654, details={'was_impossible': False}),
#  Prediction(uid='76', iid='23', r_ui=5.0, est=4.2495165736545255, details={'was_impossible': False}),
#  Prediction(uid='344', iid='708', r_ui=4.0, est=3.8618148817644036, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1478', r_ui=3.0, est=2.838230194782512, details={'was_impossible': False}),
#  Prediction(uid='267', iid='1090', r_ui=3.0, est=3.0367209140077867, details={'was_impossible': False}),
#  Prediction(uid='648', iid='497', r_ui=4.0, est=3.6006805357940928, details={'was_impossible': False}),
#  Prediction(uid='642', iid='1480', r_ui=1.0, est=3.754903923454746, details={'was_impossible': False}),
#  Prediction(uid='276', iid='428', r_ui=4.0, est=4.1831216807208955, details={'was_impossible': False}),
#  Prediction(uid='540', iid='762', r_ui=4.0, est=3.660849468821072, details={'was_impossible': False}),
#  Prediction(uid='399', iid='288', r_ui=3.0, est=2.361146841141304, details={'was_impossible': False}),
#  Prediction(uid='268', iid='250', r_ui=4.0, est=2.959812000958719, details={'was_impossible': False}),
#  Prediction(uid='349', iid='471', r_ui=3.0, est=3.5301388665795175, details={'was_impossible': False}),
#  Prediction(uid='854', iid='117', r_ui=3.0, est=2.925451070476772, details={'was_impossible': False}),
#  Prediction(uid='182', iid='845', r_ui=3.0, est=3.614768313024977, details={'was_impossible': False}),
#  Prediction(uid='773', iid='1071', r_ui=2.0, est=3.216137910206676, details={'was_impossible': False}),
#  Prediction(uid='883', iid='487', r_ui=5.0, est=4.405247176621694, details={'was_impossible': False}),
#  Prediction(uid='425', iid='258', r_ui=2.0, est=3.6866233165215885, details={'was_impossible': False}),
#  Prediction(uid='298', iid='473', r_ui=3.0, est=3.3358017717179447, details={'was_impossible': False}),
#  Prediction(uid='114', iid='269', r_ui=4.0, est=3.4782183615113715, details={'was_impossible': False}),
#  Prediction(uid='521', iid='268', r_ui=5.0, est=3.3171135447816438, details={'was_impossible': False}),
#  Prediction(uid='346', iid='318', r_ui=5.0, est=4.02856505296306, details={'was_impossible': False}),
#  Prediction(uid='752', iid='355', r_ui=2.0, est=2.701020650072315, details={'was_impossible': False}),
#  Prediction(uid='916', iid='509', r_ui=4.0, est=3.7828409361946598, details={'was_impossible': False}),
#  Prediction(uid='716', iid='117', r_ui=4.0, est=3.570902163958072, details={'was_impossible': False}),
#  Prediction(uid='269', iid='5', r_ui=2.0, est=2.2840283333600118, details={'was_impossible': False}),
#  Prediction(uid='184', iid='69', r_ui=3.0, est=3.6273718881710852, details={'was_impossible': False}),
#  Prediction(uid='174', iid='575', r_ui=1.0, est=2.7127530361514336, details={'was_impossible': False}),
#  Prediction(uid='244', iid='53', r_ui=3.0, est=3.3996324927513393, details={'was_impossible': False}),
#  Prediction(uid='200', iid='2', r_ui=4.0, est=4.022131753830878, details={'was_impossible': False}),
#  Prediction(uid='426', iid='1204', r_ui=4.0, est=3.409154372894243, details={'was_impossible': False}),
#  Prediction(uid='13', iid='846', r_ui=2.0, est=2.414070172399831, details={'was_impossible': False}),
#  Prediction(uid='661', iid='210', r_ui=5.0, est=4.030873524485329, details={'was_impossible': False}),
#  Prediction(uid='639', iid='1195', r_ui=2.0, est=2.704736028884036, details={'was_impossible': False}),
#  Prediction(uid='128', iid='133', r_ui=5.0, est=3.681361685925243, details={'was_impossible': False}),
#  Prediction(uid='357', iid='546', r_ui=5.0, est=4.0470056631936595, details={'was_impossible': False}),
#  Prediction(uid='564', iid='272', r_ui=3.0, est=4.384561951433338, details={'was_impossible': False}),
#  Prediction(uid='758', iid='576', r_ui=4.0, est=3.2679962854320177, details={'was_impossible': False}),
#  Prediction(uid='598', iid='259', r_ui=3.0, est=2.700759473672517, details={'was_impossible': False}),
#  Prediction(uid='210', iid='483', r_ui=5.0, est=4.772308932027464, details={'was_impossible': False}),
#  Prediction(uid='144', iid='960', r_ui=2.0, est=3.4200909175790684, details={'was_impossible': False}),
#  Prediction(uid='364', iid='319', r_ui=3.0, est=3.6182666671117656, details={'was_impossible': False}),
#  Prediction(uid='380', iid='300', r_ui=3.0, est=3.0389809655796345, details={'was_impossible': False}),
#  Prediction(uid='749', iid='188', r_ui=3.0, est=3.689773058501954, details={'was_impossible': False}),
#  Prediction(uid='435', iid='3', r_ui=3.0, est=3.2608536393314704, details={'was_impossible': False}),
#  Prediction(uid='244', iid='290', r_ui=3.0, est=3.463295690585984, details={'was_impossible': False}),
#  Prediction(uid='548', iid='603', r_ui=5.0, est=4.52710081077258, details={'was_impossible': False}),
#  Prediction(uid='405', iid='720', r_ui=1.0, est=1.231375064400166, details={'was_impossible': False}),
#  Prediction(uid='176', iid='240', r_ui=4.0, est=3.3567536321487847, details={'was_impossible': False}),
#  Prediction(uid='450', iid='430', r_ui=4.0, est=4.450450412630409, details={'was_impossible': False}),
#  Prediction(uid='16', iid='942', r_ui=4.0, est=4.263642530569574, details={'was_impossible': False}),
#  Prediction(uid='70', iid='197', r_ui=4.0, est=3.7217510730167422, details={'was_impossible': False}),
#  Prediction(uid='940', iid='354', r_ui=5.0, est=2.7077855438735465, details={'was_impossible': False}),
#  Prediction(uid='551', iid='366', r_ui=5.0, est=4.005775945148551, details={'was_impossible': False}),
#  Prediction(uid='920', iid='300', r_ui=3.0, est=3.335484094106248, details={'was_impossible': False}),
#  Prediction(uid='130', iid='210', r_ui=5.0, est=4.625696345403111, details={'was_impossible': False}),
#  Prediction(uid='7', iid='608', r_ui=4.0, est=4.261670991426912, details={'was_impossible': False}),
#  Prediction(uid='886', iid='1324', r_ui=2.0, est=2.933901324430569, details={'was_impossible': False}),
#  Prediction(uid='880', iid='316', r_ui=5.0, est=4.321349059638611, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1142', r_ui=2.0, est=3.635596164217605, details={'was_impossible': False}),
#  Prediction(uid='385', iid='506', r_ui=2.0, est=3.642333067037846, details={'was_impossible': False}),
#  Prediction(uid='313', iid='237', r_ui=2.0, est=3.552875075725973, details={'was_impossible': False}),
#  Prediction(uid='32', iid='288', r_ui=4.0, est=2.926685252483559, details={'was_impossible': False}),
#  Prediction(uid='76', iid='547', r_ui=2.0, est=3.3017363673926674, details={'was_impossible': False}),
#  Prediction(uid='892', iid='515', r_ui=5.0, est=4.597035029264929, details={'was_impossible': False}),
#  Prediction(uid='823', iid='66', r_ui=4.0, est=3.6809023990783096, details={'was_impossible': False}),
#  Prediction(uid='416', iid='300', r_ui=4.0, est=4.208324463491664, details={'was_impossible': False}),
#  Prediction(uid='318', iid='205', r_ui=3.0, est=4.164426626605623, details={'was_impossible': False}),
#  Prediction(uid='450', iid='485', r_ui=5.0, est=4.2635728368101855, details={'was_impossible': False}),
#  Prediction(uid='416', iid='827', r_ui=4.0, est=3.0289170449602283, details={'was_impossible': False}),
#  Prediction(uid='412', iid='684', r_ui=4.0, est=3.9238681362720738, details={'was_impossible': False}),
#  Prediction(uid='682', iid='196', r_ui=5.0, est=3.919163253219581, details={'was_impossible': False}),
#  Prediction(uid='110', iid='1090', r_ui=2.0, est=2.2388328278718483, details={'was_impossible': False}),
#  Prediction(uid='521', iid='755', r_ui=3.0, est=2.8677297014834373, details={'was_impossible': False}),
#  Prediction(uid='861', iid='289', r_ui=5.0, est=3.151843091673848, details={'was_impossible': False}),
#  Prediction(uid='712', iid='584', r_ui=4.0, est=3.927809767279608, details={'was_impossible': False}),
#  Prediction(uid='568', iid='923', r_ui=3.0, est=3.8130152297423647, details={'was_impossible': False}),
#  Prediction(uid='921', iid='15', r_ui=4.0, est=4.004770533490177, details={'was_impossible': False}),
#  Prediction(uid='815', iid='494', r_ui=5.0, est=3.57335657041328, details={'was_impossible': False}),
#  Prediction(uid='523', iid='549', r_ui=4.0, est=4.43075651224961, details={'was_impossible': False}),
#  Prediction(uid='846', iid='566', r_ui=5.0, est=3.911219976595975, details={'was_impossible': False}),
#  Prediction(uid='184', iid='165', r_ui=4.0, est=3.9760960421392344, details={'was_impossible': False}),
#  Prediction(uid='556', iid='513', r_ui=4.0, est=4.7923367148673375, details={'was_impossible': False}),
#  Prediction(uid='378', iid='13', r_ui=3.0, est=3.543068449027192, details={'was_impossible': False}),
#  Prediction(uid='870', iid='690', r_ui=2.0, est=3.034895159460113, details={'was_impossible': False}),
#  Prediction(uid='534', iid='628', r_ui=5.0, est=4.113963448006517, details={'was_impossible': False}),
#  Prediction(uid='851', iid='192', r_ui=4.0, est=4.151931680990516, details={'was_impossible': False}),
#  Prediction(uid='445', iid='310', r_ui=1.0, est=1.7094384648794452, details={'was_impossible': False}),
#  Prediction(uid='380', iid='62', r_ui=1.0, est=2.709959426281147, details={'was_impossible': False}),
#  Prediction(uid='26', iid='50', r_ui=4.0, est=3.790587541044461, details={'was_impossible': False}),
#  Prediction(uid='319', iid='338', r_ui=2.0, est=2.961872109717707, details={'was_impossible': False}),
#  Prediction(uid='97', iid='82', r_ui=4.0, est=4.129392717042188, details={'was_impossible': False}),
#  Prediction(uid='618', iid='117', r_ui=5.0, est=3.092668037116948, details={'was_impossible': False}),
#  Prediction(uid='642', iid='217', r_ui=2.0, est=4.2534021223305984, details={'was_impossible': False}),
#  Prediction(uid='913', iid='317', r_ui=4.0, est=3.5711555381361846, details={'was_impossible': False}),
#  Prediction(uid='919', iid='174', r_ui=4.0, est=4.391591526384897, details={'was_impossible': False}),
#  Prediction(uid='870', iid='715', r_ui=3.0, est=3.3284027541765404, details={'was_impossible': False}),
#  Prediction(uid='405', iid='415', r_ui=2.0, est=1.5150381510308824, details={'was_impossible': False}),
#  Prediction(uid='217', iid='144', r_ui=4.0, est=2.7985140944661904, details={'was_impossible': False}),
#  Prediction(uid='109', iid='845', r_ui=4.0, est=3.7267496964513644, details={'was_impossible': False}),
#  Prediction(uid='642', iid='409', r_ui=5.0, est=3.322085757874874, details={'was_impossible': False}),
#  Prediction(uid='894', iid='818', r_ui=3.0, est=2.7195093080683024, details={'was_impossible': False}),
#  Prediction(uid='340', iid='174', r_ui=4.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='790', iid='403', r_ui=4.0, est=2.8846145789529536, details={'was_impossible': False}),
#  Prediction(uid='282', iid='307', r_ui=3.0, est=3.5921207950650107, details={'was_impossible': False}),
#  Prediction(uid='586', iid='164', r_ui=2.0, est=3.4928368312773284, details={'was_impossible': False}),
#  Prediction(uid='130', iid='2', r_ui=4.0, est=3.656555478524293, details={'was_impossible': False}),
#  Prediction(uid='506', iid='198', r_ui=2.0, est=4.189449089534505, details={'was_impossible': False}),
#  Prediction(uid='943', iid='210', r_ui=4.0, est=3.388458341581012, details={'was_impossible': False}),
#  Prediction(uid='363', iid='39', r_ui=4.0, est=2.530888495694082, details={'was_impossible': False}),
#  Prediction(uid='94', iid='1226', r_ui=4.0, est=3.493101996356429, details={'was_impossible': False}),
#  Prediction(uid='389', iid='238', r_ui=5.0, est=4.050519599642342, details={'was_impossible': False}),
#  Prediction(uid='624', iid='979', r_ui=4.0, est=3.446927039720972, details={'was_impossible': False}),
#  Prediction(uid='860', iid='865', r_ui=4.0, est=3.4274134576681408, details={'was_impossible': False}),
#  Prediction(uid='908', iid='144', r_ui=4.0, est=3.562852638443533, details={'was_impossible': False}),
#  Prediction(uid='122', iid='46', r_ui=5.0, est=3.962038611907777, details={'was_impossible': False}),
#  Prediction(uid='48', iid='680', r_ui=3.0, est=2.95491888205562, details={'was_impossible': False}),
#  Prediction(uid='805', iid='141', r_ui=2.0, est=3.6232965245847017, details={'was_impossible': False}),
#  Prediction(uid='347', iid='157', r_ui=5.0, est=3.5304098229688115, details={'was_impossible': False}),
#  Prediction(uid='520', iid='100', r_ui=4.0, est=3.9797923406333995, details={'was_impossible': False}),
#  Prediction(uid='234', iid='436', r_ui=3.0, est=3.052204125500008, details={'was_impossible': False}),
#  Prediction(uid='397', iid='134', r_ui=5.0, est=4.401959185914643, details={'was_impossible': False}),
#  Prediction(uid='92', iid='1014', r_ui=3.0, est=2.6840939936667527, details={'was_impossible': False}),
#  Prediction(uid='210', iid='722', r_ui=4.0, est=3.4003732554818105, details={'was_impossible': False}),
#  Prediction(uid='158', iid='277', r_ui=4.0, est=3.783340387759107, details={'was_impossible': False}),
#  Prediction(uid='916', iid='549', r_ui=3.0, est=3.663277279253008, details={'was_impossible': False}),
#  Prediction(uid='790', iid='145', r_ui=2.0, est=2.128688677377053, details={'was_impossible': False}),
#  Prediction(uid='724', iid='877', r_ui=1.0, est=1.4372307330032976, details={'was_impossible': False}),
#  Prediction(uid='234', iid='451', r_ui=3.0, est=2.524268923328619, details={'was_impossible': False}),
#  Prediction(uid='250', iid='44', r_ui=4.0, est=3.6163467656851336, details={'was_impossible': False}),
#  Prediction(uid='94', iid='412', r_ui=2.0, est=2.655357639016937, details={'was_impossible': False}),
#  Prediction(uid='25', iid='495', r_ui=4.0, est=3.7810678571258496, details={'was_impossible': False}),
#  Prediction(uid='421', iid='175', r_ui=2.0, est=4.084704703333996, details={'was_impossible': False}),
#  Prediction(uid='429', iid='768', r_ui=3.0, est=2.9224219252090577, details={'was_impossible': False}),
#  Prediction(uid='536', iid='163', r_ui=5.0, est=3.506321253888174, details={'was_impossible': False}),
#  Prediction(uid='115', iid='969', r_ui=1.0, est=3.8670506363828947, details={'was_impossible': False}),
#  Prediction(uid='339', iid='508', r_ui=4.0, est=4.51458355658697, details={'was_impossible': False}),
#  Prediction(uid='303', iid='357', r_ui=5.0, est=4.506941832338234, details={'was_impossible': False}),
#  Prediction(uid='608', iid='507', r_ui=3.0, est=3.820469300563809, details={'was_impossible': False}),
#  Prediction(uid='712', iid='232', r_ui=3.0, est=3.9006281671484575, details={'was_impossible': False}),
#  Prediction(uid='883', iid='198', r_ui=5.0, est=4.2362514807061356, details={'was_impossible': False}),
#  Prediction(uid='603', iid='173', r_ui=4.0, est=4.110620777849888, details={'was_impossible': False}),
#  Prediction(uid='225', iid='603', r_ui=5.0, est=4.631314009201167, details={'was_impossible': False}),
#  Prediction(uid='655', iid='218', r_ui=3.0, est=3.0647681606628536, details={'was_impossible': False}),
#  Prediction(uid='643', iid='162', r_ui=3.0, est=3.89410454808437, details={'was_impossible': False}),
#  Prediction(uid='303', iid='479', r_ui=5.0, est=4.015872795857449, details={'was_impossible': False}),
#  Prediction(uid='145', iid='56', r_ui=5.0, est=3.781539307508369, details={'was_impossible': False}),
#  Prediction(uid='428', iid='268', r_ui=4.0, est=4.5259359511034205, details={'was_impossible': False}),
#  Prediction(uid='189', iid='7', r_ui=3.0, est=3.7813279562235715, details={'was_impossible': False}),
#  Prediction(uid='409', iid='45', r_ui=4.0, est=3.6882627857532984, details={'was_impossible': False}),
#  Prediction(uid='245', iid='133', r_ui=2.0, est=3.9599480473125324, details={'was_impossible': False}),
#  Prediction(uid='41', iid='28', r_ui=4.0, est=3.9112649663529377, details={'was_impossible': False}),
#  Prediction(uid='541', iid='810', r_ui=3.0, est=3.410340003124834, details={'was_impossible': False}),
#  Prediction(uid='846', iid='1209', r_ui=1.0, est=2.9423923747037874, details={'was_impossible': False}),
#  Prediction(uid='49', iid='1018', r_ui=2.0, est=2.956799471706106, details={'was_impossible': False}),
#  Prediction(uid='410', iid='352', r_ui=3.0, est=2.1421201468544284, details={'was_impossible': False}),
#  Prediction(uid='234', iid='216', r_ui=3.0, est=3.5547495540344785, details={'was_impossible': False}),
#  Prediction(uid='130', iid='331', r_ui=3.0, est=3.903946384964184, details={'was_impossible': False}),
#  Prediction(uid='363', iid='222', r_ui=5.0, est=3.2346649632060025, details={'was_impossible': False}),
#  Prediction(uid='435', iid='930', r_ui=3.0, est=2.2552331548688094, details={'was_impossible': False}),
#  Prediction(uid='244', iid='1119', r_ui=5.0, est=3.5996342749974826, details={'was_impossible': False}),
#  Prediction(uid='839', iid='950', r_ui=4.0, est=2.8620094859704537, details={'was_impossible': False}),
#  Prediction(uid='320', iid='472', r_ui=3.0, est=3.6038688603433378, details={'was_impossible': False}),
#  Prediction(uid='305', iid='190', r_ui=3.0, est=3.520442060783923, details={'was_impossible': False}),
#  Prediction(uid='293', iid='632', r_ui=3.0, est=3.6379286171927285, details={'was_impossible': False}),
#  Prediction(uid='457', iid='443', r_ui=4.0, est=4.503570705363886, details={'was_impossible': False}),
#  Prediction(uid='261', iid='259', r_ui=4.0, est=3.4832137954405966, details={'was_impossible': False}),
#  Prediction(uid='658', iid='168', r_ui=3.0, est=3.754797560480569, details={'was_impossible': False}),
#  Prediction(uid='684', iid='742', r_ui=4.0, est=3.799416125737348, details={'was_impossible': False}),
#  Prediction(uid='532', iid='501', r_ui=5.0, est=3.944401244373963, details={'was_impossible': False}),
#  Prediction(uid='545', iid='326', r_ui=3.0, est=3.2078233124726987, details={'was_impossible': False}),
#  Prediction(uid='498', iid='174', r_ui=3.0, est=3.6479625065569974, details={'was_impossible': False}),
#  Prediction(uid='158', iid='433', r_ui=3.0, est=4.0116815666255174, details={'was_impossible': False}),
#  Prediction(uid='18', iid='216', r_ui=4.0, est=4.2458286314277265, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1435', r_ui=3.0, est=3.1054054029077833, details={'was_impossible': False}),
#  Prediction(uid='813', iid='9', r_ui=3.0, est=3.4886848301673723, details={'was_impossible': False}),
#  Prediction(uid='585', iid='1319', r_ui=2.0, est=3.2349794627855646, details={'was_impossible': False}),
#  Prediction(uid='158', iid='502', r_ui=4.0, est=4.009835637219739, details={'was_impossible': False}),
#  Prediction(uid='259', iid='357', r_ui=5.0, est=4.582835646940114, details={'was_impossible': False}),
#  Prediction(uid='160', iid='273', r_ui=5.0, est=3.901258699273789, details={'was_impossible': False}),
#  Prediction(uid='567', iid='192', r_ui=4.0, est=4.318504279905096, details={'was_impossible': False}),
#  Prediction(uid='62', iid='283', r_ui=4.0, est=3.504580524534313, details={'was_impossible': False}),
#  Prediction(uid='916', iid='204', r_ui=3.0, est=3.6104846609042385, details={'was_impossible': False}),
#  Prediction(uid='738', iid='528', r_ui=4.0, est=4.01485473147895, details={'was_impossible': False}),
#  Prediction(uid='23', iid='541', r_ui=4.0, est=2.528634715520629, details={'was_impossible': False}),
#  Prediction(uid='643', iid='50', r_ui=4.0, est=4.297857231638165, details={'was_impossible': False}),
#  Prediction(uid='437', iid='692', r_ui=4.0, est=3.836903043541041, details={'was_impossible': False}),
#  Prediction(uid='1', iid='117', r_ui=3.0, est=3.3299854393894415, details={'was_impossible': False}),
#  Prediction(uid='559', iid='194', r_ui=3.0, est=3.9304464879013263, details={'was_impossible': False}),
#  Prediction(uid='805', iid='431', r_ui=1.0, est=3.3676367791090533, details={'was_impossible': False}),
#  Prediction(uid='248', iid='96', r_ui=4.0, est=3.8055830688581724, details={'was_impossible': False}),
#  Prediction(uid='222', iid='195', r_ui=4.0, est=4.3987768313231355, details={'was_impossible': False}),
#  Prediction(uid='886', iid='49', r_ui=4.0, est=3.1439799109312285, details={'was_impossible': False}),
#  Prediction(uid='323', iid='744', r_ui=5.0, est=3.406213513100447, details={'was_impossible': False}),
#  Prediction(uid='368', iid='777', r_ui=2.0, est=2.9612336703265623, details={'was_impossible': False}),
#  Prediction(uid='796', iid='684', r_ui=5.0, est=3.8884948617877355, details={'was_impossible': False}),
#  Prediction(uid='624', iid='845', r_ui=3.0, est=3.7716556282572427, details={'was_impossible': False}),
#  Prediction(uid='492', iid='242', r_ui=5.0, est=3.3940056307548687, details={'was_impossible': False}),
#  Prediction(uid='932', iid='498', r_ui=5.0, est=4.384389267903895, details={'was_impossible': False}),
#  Prediction(uid='303', iid='1199', r_ui=3.0, est=3.17744402700674, details={'was_impossible': False}),
#  Prediction(uid='796', iid='217', r_ui=4.0, est=3.4968996311377203, details={'was_impossible': False}),
#  Prediction(uid='915', iid='302', r_ui=4.0, est=3.8651395585059327, details={'was_impossible': False}),
#  Prediction(uid='318', iid='768', r_ui=2.0, est=3.5977360385454205, details={'was_impossible': False}),
#  Prediction(uid='454', iid='1190', r_ui=3.0, est=2.361824315591974, details={'was_impossible': False}),
#  Prediction(uid='268', iid='217', r_ui=2.0, est=2.7818503325233555, details={'was_impossible': False}),
#  Prediction(uid='864', iid='736', r_ui=5.0, est=4.136735952268771, details={'was_impossible': False}),
#  Prediction(uid='417', iid='827', r_ui=2.0, est=2.4818952360010447, details={'was_impossible': False}),
#  Prediction(uid='918', iid='86', r_ui=4.0, est=3.7217127652542876, details={'was_impossible': False}),
#  Prediction(uid='753', iid='64', r_ui=4.0, est=4.285438414060483, details={'was_impossible': False}),
#  Prediction(uid='406', iid='150', r_ui=4.0, est=3.714247473452544, details={'was_impossible': False}),
#  Prediction(uid='308', iid='169', r_ui=5.0, est=4.690849242728314, details={'was_impossible': False}),
#  Prediction(uid='650', iid='212', r_ui=3.0, est=2.6661253273209367, details={'was_impossible': False}),
#  Prediction(uid='221', iid='1016', r_ui=3.0, est=3.3599271289643178, details={'was_impossible': False}),
#  Prediction(uid='160', iid='56', r_ui=5.0, est=4.633623183945417, details={'was_impossible': False}),
#  Prediction(uid='244', iid='815', r_ui=4.0, est=3.231198194617924, details={'was_impossible': False}),
#  Prediction(uid='554', iid='13', r_ui=2.0, est=2.9733397841019102, details={'was_impossible': False}),
#  Prediction(uid='94', iid='173', r_ui=4.0, est=4.152267674635246, details={'was_impossible': False}),
#  Prediction(uid='642', iid='218', r_ui=3.0, est=3.4855050017965037, details={'was_impossible': False}),
#  Prediction(uid='933', iid='180', r_ui=5.0, est=3.4459232186026862, details={'was_impossible': False}),
#  Prediction(uid='149', iid='321', r_ui=2.0, est=2.5358440834222966, details={'was_impossible': False}),
#  Prediction(uid='396', iid='245', r_ui=3.0, est=3.268668050676276, details={'was_impossible': False}),
#  Prediction(uid='935', iid='405', r_ui=4.0, est=3.9241470820422113, details={'was_impossible': False}),
#  Prediction(uid='212', iid='382', r_ui=5.0, est=3.3134172935224155, details={'was_impossible': False}),
#  Prediction(uid='666', iid='288', r_ui=3.0, est=3.0406933354687795, details={'was_impossible': False}),
#  Prediction(uid='125', iid='427', r_ui=4.0, est=3.8641183303610713, details={'was_impossible': False}),
#  Prediction(uid='321', iid='513', r_ui=4.0, est=4.192230934347932, details={'was_impossible': False}),
#  Prediction(uid='305', iid='655', r_ui=4.0, est=3.358653169232969, details={'was_impossible': False}),
#  Prediction(uid='269', iid='1101', r_ui=4.0, est=3.3907490211165574, details={'was_impossible': False}),
#  Prediction(uid='654', iid='476', r_ui=3.0, est=3.1275991401154495, details={'was_impossible': False}),
#  Prediction(uid='193', iid='682', r_ui=1.0, est=3.5305253978388853, details={'was_impossible': False}),
#  Prediction(uid='419', iid='306', r_ui=5.0, est=4.252995332708227, details={'was_impossible': False}),
#  Prediction(uid='113', iid='742', r_ui=3.0, est=3.98466622465405, details={'was_impossible': False}),
#  Prediction(uid='634', iid='1048', r_ui=3.0, est=3.090371964926524, details={'was_impossible': False}),
#  Prediction(uid='911', iid='530', r_ui=4.0, est=4.124794141707384, details={'was_impossible': False}),
#  Prediction(uid='280', iid='322', r_ui=4.0, est=3.166292158618813, details={'was_impossible': False}),
#  Prediction(uid='871', iid='346', r_ui=3.0, est=3.49405928116239, details={'was_impossible': False}),
#  Prediction(uid='275', iid='1', r_ui=4.0, est=3.573129975393958, details={'was_impossible': False}),
#  Prediction(uid='770', iid='294', r_ui=3.0, est=4.0502058803890995, details={'was_impossible': False}),
#  Prediction(uid='221', iid='1067', r_ui=3.0, est=3.7729621354569307, details={'was_impossible': False}),
#  Prediction(uid='162', iid='230', r_ui=2.0, est=3.705049345536445, details={'was_impossible': False}),
#  Prediction(uid='489', iid='897', r_ui=2.0, est=3.7036368920512497, details={'was_impossible': False}),
#  Prediction(uid='95', iid='181', r_ui=4.0, est=3.642152644299512, details={'was_impossible': False}),
#  Prediction(uid='273', iid='319', r_ui=4.0, est=3.1325232060296124, details={'was_impossible': False}),
#  Prediction(uid='843', iid='627', r_ui=2.0, est=2.422803305724575, details={'was_impossible': False}),
#  Prediction(uid='763', iid='111', r_ui=2.0, est=3.7809170452849017, details={'was_impossible': False}),
#  Prediction(uid='659', iid='134', r_ui=4.0, est=4.399458862613232, details={'was_impossible': False}),
#  Prediction(uid='707', iid='770', r_ui=3.0, est=3.194800080313512, details={'was_impossible': False}),
#  Prediction(uid='792', iid='844', r_ui=4.0, est=3.1715571884466867, details={'was_impossible': False}),
#  Prediction(uid='134', iid='294', r_ui=4.0, est=3.608793370891573, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1203', r_ui=3.0, est=3.564301507117151, details={'was_impossible': False}),
#  Prediction(uid='892', iid='401', r_ui=3.0, est=2.980984392274934, details={'was_impossible': False}),
#  Prediction(uid='822', iid='432', r_ui=3.0, est=3.572700045038859, details={'was_impossible': False}),
#  Prediction(uid='521', iid='159', r_ui=3.0, est=2.7283528796816063, details={'was_impossible': False}),
#  Prediction(uid='661', iid='427', r_ui=4.0, est=4.577028155050015, details={'was_impossible': False}),
#  Prediction(uid='542', iid='427', r_ui=5.0, est=4.172772838356908, details={'was_impossible': False}),
#  Prediction(uid='25', iid='177', r_ui=3.0, est=4.213596708812262, details={'was_impossible': False}),
#  Prediction(uid='886', iid='11', r_ui=5.0, est=3.7349295133288614, details={'was_impossible': False}),
#  Prediction(uid='394', iid='795', r_ui=2.0, est=3.264193297406394, details={'was_impossible': False}),
#  Prediction(uid='90', iid='904', r_ui=3.0, est=4.085456470150635, details={'was_impossible': False}),
#  Prediction(uid='320', iid='292', r_ui=3.0, est=4.0541826562144685, details={'was_impossible': False}),
#  Prediction(uid='614', iid='293', r_ui=3.0, est=3.8561236559644394, details={'was_impossible': False}),
#  Prediction(uid='372', iid='561', r_ui=5.0, est=4.012868794034451, details={'was_impossible': False}),
#  Prediction(uid='712', iid='365', r_ui=3.0, est=4.146947687809247, details={'was_impossible': False}),
#  Prediction(uid='170', iid='245', r_ui=5.0, est=3.676781154279779, details={'was_impossible': False}),
#  Prediction(uid='592', iid='194', r_ui=4.0, est=4.018669557875136, details={'was_impossible': False}),
#  Prediction(uid='894', iid='639', r_ui=5.0, est=4.049787242237899, details={'was_impossible': False}),
#  Prediction(uid='431', iid='286', r_ui=4.0, est=3.8284598782527453, details={'was_impossible': False}),
#  Prediction(uid='334', iid='129', r_ui=4.0, est=3.9453833290341263, details={'was_impossible': False}),
#  Prediction(uid='670', iid='96', r_ui=5.0, est=4.277457261582034, details={'was_impossible': False}),
#  Prediction(uid='790', iid='1044', r_ui=4.0, est=2.761339493355146, details={'was_impossible': False}),
#  Prediction(uid='889', iid='128', r_ui=5.0, est=3.1176842389645696, details={'was_impossible': False}),
#  Prediction(uid='796', iid='143', r_ui=5.0, est=4.034383957123342, details={'was_impossible': False}),
#  Prediction(uid='543', iid='462', r_ui=4.0, est=3.6670346008713333, details={'was_impossible': False}),
#  Prediction(uid='648', iid='586', r_ui=3.0, est=2.8802699725784358, details={'was_impossible': False}),
#  Prediction(uid='503', iid='97', r_ui=4.0, est=4.27091181079664, details={'was_impossible': False}),
#  Prediction(uid='73', iid='382', r_ui=4.0, est=3.509924240021557, details={'was_impossible': False}),
#  Prediction(uid='342', iid='813', r_ui=5.0, est=4.0163885817169795, details={'was_impossible': False}),
#  Prediction(uid='311', iid='131', r_ui=3.0, est=3.5346317303246755, details={'was_impossible': False}),
#  Prediction(uid='7', iid='594', r_ui=3.0, est=3.7783296980033945, details={'was_impossible': False}),
#  Prediction(uid='416', iid='64', r_ui=5.0, est=4.675061536671354, details={'was_impossible': False}),
#  Prediction(uid='398', iid='523', r_ui=4.0, est=3.754395429930883, details={'was_impossible': False}),
#  Prediction(uid='458', iid='190', r_ui=4.0, est=3.9695524078838735, details={'was_impossible': False}),
#  Prediction(uid='246', iid='101', r_ui=2.0, est=2.7734546688022084, details={'was_impossible': False}),
#  Prediction(uid='694', iid='434', r_ui=5.0, est=4.104849279579061, details={'was_impossible': False}),
#  Prediction(uid='537', iid='942', r_ui=3.0, est=2.8230233101409805, details={'was_impossible': False}),
#  Prediction(uid='160', iid='234', r_ui=5.0, est=4.143173317327597, details={'was_impossible': False}),
#  Prediction(uid='160', iid='603', r_ui=4.0, est=4.6631253954215435, details={'was_impossible': False}),
#  Prediction(uid='440', iid='886', r_ui=5.0, est=3.540191705712367, details={'was_impossible': False}),
#  Prediction(uid='716', iid='234', r_ui=5.0, est=4.136854201966254, details={'was_impossible': False}),
#  Prediction(uid='270', iid='443', r_ui=3.0, est=4.903650510290849, details={'was_impossible': False}),
#  Prediction(uid='389', iid='210', r_ui=2.0, est=3.6490140829376116, details={'was_impossible': False}),
#  Prediction(uid='506', iid='746', r_ui=5.0, est=3.818852597078626, details={'was_impossible': False}),
#  Prediction(uid='279', iid='654', r_ui=5.0, est=3.608337286962394, details={'was_impossible': False}),
#  Prediction(uid='280', iid='282', r_ui=3.0, est=3.7258623343068384, details={'was_impossible': False}),
#  Prediction(uid='271', iid='510', r_ui=4.0, est=3.972362105791858, details={'was_impossible': False}),
#  Prediction(uid='346', iid='642', r_ui=3.0, est=3.377117407113683, details={'was_impossible': False}),
#  Prediction(uid='199', iid='323', r_ui=3.0, est=2.540979013851867, details={'was_impossible': False}),
#  Prediction(uid='286', iid='95', r_ui=5.0, est=4.585666320043849, details={'was_impossible': False}),
#  Prediction(uid='472', iid='418', r_ui=3.0, est=4.4522228462690325, details={'was_impossible': False}),
#  Prediction(uid='92', iid='561', r_ui=3.0, est=2.96964736637407, details={'was_impossible': False}),
#  Prediction(uid='331', iid='1141', r_ui=3.0, est=3.2351027432582473, details={'was_impossible': False}),
#  Prediction(uid='270', iid='156', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='705', iid='566', r_ui=4.0, est=3.883512220010903, details={'was_impossible': False}),
#  Prediction(uid='782', iid='331', r_ui=3.0, est=2.911608346022805, details={'was_impossible': False}),
#  Prediction(uid='117', iid='405', r_ui=5.0, est=3.6847375739269737, details={'was_impossible': False}),
#  Prediction(uid='843', iid='101', r_ui=3.0, est=2.338798793519635, details={'was_impossible': False}),
#  Prediction(uid='459', iid='1060', r_ui=1.0, est=3.132540136559202, details={'was_impossible': False}),
#  Prediction(uid='752', iid='327', r_ui=5.0, est=3.102182064993052, details={'was_impossible': False}),
#  Prediction(uid='710', iid='258', r_ui=2.0, est=3.462227011907318, details={'was_impossible': False}),
#  Prediction(uid='861', iid='463', r_ui=3.0, est=4.294627270950906, details={'was_impossible': False}),
#  Prediction(uid='276', iid='332', r_ui=4.0, est=3.245134383652028, details={'was_impossible': False}),
#  Prediction(uid='618', iid='144', r_ui=4.0, est=3.2665413671688786, details={'was_impossible': False}),
#  Prediction(uid='151', iid='461', r_ui=4.0, est=3.905492500800574, details={'was_impossible': False}),
#  Prediction(uid='844', iid='1474', r_ui=4.0, est=3.1129329238883523, details={'was_impossible': False}),
#  Prediction(uid='308', iid='69', r_ui=2.0, est=3.8308345010090648, details={'was_impossible': False}),
#  Prediction(uid='548', iid='275', r_ui=3.0, est=4.0378154327383555, details={'was_impossible': False}),
#  Prediction(uid='287', iid='252', r_ui=1.0, est=3.1228550311381995, details={'was_impossible': False}),
#  Prediction(uid='56', iid='399', r_ui=4.0, est=3.6020543482153187, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1210', r_ui=3.0, est=2.6764598200923815, details={'was_impossible': False}),
#  Prediction(uid='943', iid='217', r_ui=3.0, est=3.807108480822642, details={'was_impossible': False}),
#  Prediction(uid='535', iid='942', r_ui=4.0, est=3.6801293451865944, details={'was_impossible': False}),
#  Prediction(uid='536', iid='164', r_ui=4.0, est=3.7522242549994007, details={'was_impossible': False}),
#  Prediction(uid='43', iid='684', r_ui=4.0, est=4.1644630707459935, details={'was_impossible': False}),
#  Prediction(uid='497', iid='403', r_ui=3.0, est=3.3103568456318153, details={'was_impossible': False}),
#  Prediction(uid='450', iid='739', r_ui=4.0, est=3.5421452480816793, details={'was_impossible': False}),
#  Prediction(uid='13', iid='138', r_ui=1.0, est=2.6545142408035316, details={'was_impossible': False}),
#  Prediction(uid='233', iid='47', r_ui=5.0, est=3.9939265562226094, details={'was_impossible': False}),
#  Prediction(uid='104', iid='984', r_ui=1.0, est=2.103742813665607, details={'was_impossible': False}),
#  Prediction(uid='249', iid='478', r_ui=4.0, est=4.402573502663907, details={'was_impossible': False}),
#  Prediction(uid='593', iid='51', r_ui=3.0, est=3.3767352888038076, details={'was_impossible': False}),
#  Prediction(uid='455', iid='258', r_ui=5.0, est=4.081248725806807, details={'was_impossible': False}),
#  Prediction(uid='741', iid='781', r_ui=4.0, est=3.333003475033301, details={'was_impossible': False}),
#  Prediction(uid='686', iid='1184', r_ui=1.0, est=3.919521897212482, details={'was_impossible': False}),
#  Prediction(uid='441', iid='121', r_ui=4.0, est=3.517353874077893, details={'was_impossible': False}),
#  Prediction(uid='566', iid='202', r_ui=4.0, est=3.4423667557480493, details={'was_impossible': False}),
#  Prediction(uid='450', iid='388', r_ui=3.0, est=2.736835165579105, details={'was_impossible': False}),
#  Prediction(uid='182', iid='150', r_ui=3.0, est=3.9052391228157943, details={'was_impossible': False}),
#  Prediction(uid='407', iid='747', r_ui=3.0, est=3.555065018251987, details={'was_impossible': False}),
#  Prediction(uid='44', iid='591', r_ui=4.0, est=3.6179648893398255, details={'was_impossible': False}),
#  Prediction(uid='840', iid='423', r_ui=5.0, est=4.160222633216642, details={'was_impossible': False}),
#  Prediction(uid='452', iid='1109', r_ui=2.0, est=3.1967203548088996, details={'was_impossible': False}),
#  Prediction(uid='560', iid='606', r_ui=4.0, est=3.9054950143173173, details={'was_impossible': False}),
#  Prediction(uid='506', iid='550', r_ui=4.0, est=3.5910738317985467, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1242', r_ui=2.0, est=3.2414186389229975, details={'was_impossible': False}),
#  Prediction(uid='416', iid='202', r_ui=4.0, est=4.036465254184395, details={'was_impossible': False}),
#  Prediction(uid='907', iid='619', r_ui=2.0, est=4.507297865038153, details={'was_impossible': False}),
#  Prediction(uid='370', iid='210', r_ui=3.0, est=3.5840081774230668, details={'was_impossible': False}),
#  Prediction(uid='881', iid='443', r_ui=5.0, est=3.7406491889723466, details={'was_impossible': False}),
#  Prediction(uid='844', iid='117', r_ui=4.0, est=3.6597802320607284, details={'was_impossible': False}),
#  Prediction(uid='875', iid='651', r_ui=5.0, est=4.411796712399676, details={'was_impossible': False}),
#  Prediction(uid='201', iid='1220', r_ui=2.0, est=2.6918343463259897, details={'was_impossible': False}),
#  Prediction(uid='152', iid='549', r_ui=4.0, est=4.457445051136407, details={'was_impossible': False}),
#  Prediction(uid='659', iid='712', r_ui=3.0, est=3.40518476411633, details={'was_impossible': False}),
#  Prediction(uid='930', iid='756', r_ui=3.0, est=2.2964373189821443, details={'was_impossible': False}),
#  Prediction(uid='648', iid='9', r_ui=1.0, est=3.8405411202878703, details={'was_impossible': False}),
#  Prediction(uid='108', iid='121', r_ui=3.0, est=2.839275169613487, details={'was_impossible': False}),
#  Prediction(uid='532', iid='367', r_ui=5.0, est=4.190309757455496, details={'was_impossible': False}),
#  Prediction(uid='738', iid='50', r_ui=5.0, est=4.49640925257582, details={'was_impossible': False}),
#  Prediction(uid='537', iid='923', r_ui=3.0, est=3.4510309029362407, details={'was_impossible': False}),
#  Prediction(uid='73', iid='202', r_ui=2.0, est=3.5919539157045928, details={'was_impossible': False}),
#  Prediction(uid='722', iid='300', r_ui=3.0, est=4.0331956276725425, details={'was_impossible': False}),
#  Prediction(uid='656', iid='327', r_ui=2.0, est=3.031009982881092, details={'was_impossible': False}),
#  Prediction(uid='399', iid='22', r_ui=3.0, est=3.453171695911033, details={'was_impossible': False}),
#  Prediction(uid='321', iid='704', r_ui=3.0, est=3.2183675690461904, details={'was_impossible': False}),
#  Prediction(uid='747', iid='11', r_ui=5.0, est=4.134151800679098, details={'was_impossible': False}),
#  Prediction(uid='588', iid='110', r_ui=3.0, est=3.075214485352079, details={'was_impossible': False}),
#  Prediction(uid='59', iid='606', r_ui=4.0, est=4.343786965974979, details={'was_impossible': False}),
#  Prediction(uid='794', iid='475', r_ui=5.0, est=4.294171369564853, details={'was_impossible': False}),
#  Prediction(uid='626', iid='286', r_ui=5.0, est=3.1432741119976098, details={'was_impossible': False}),
#  Prediction(uid='388', iid='690', r_ui=5.0, est=3.95008528830271, details={'was_impossible': False}),
#  Prediction(uid='334', iid='19', r_ui=4.0, est=3.912456355718774, details={'was_impossible': False}),
#  Prediction(uid='248', iid='181', r_ui=4.0, est=3.8860828166485817, details={'was_impossible': False}),
#  Prediction(uid='327', iid='169', r_ui=2.0, est=4.221670432656007, details={'was_impossible': False}),
#  Prediction(uid='417', iid='120', r_ui=2.0, est=2.1063507160424786, details={'was_impossible': False}),
#  Prediction(uid='883', iid='195', r_ui=5.0, est=3.887661597889852, details={'was_impossible': False}),
#  Prediction(uid='332', iid='229', r_ui=5.0, est=4.102188702749149, details={'was_impossible': False}),
#  Prediction(uid='541', iid='843', r_ui=4.0, est=3.5531323143788813, details={'was_impossible': False}),
#  Prediction(uid='458', iid='199', r_ui=4.0, est=4.326882479495001, details={'was_impossible': False}),
#  Prediction(uid='370', iid='193', r_ui=4.0, est=3.9178535057629804, details={'was_impossible': False}),
#  Prediction(uid='788', iid='781', r_ui=3.0, est=2.9330496966798902, details={'was_impossible': False}),
#  Prediction(uid='236', iid='71', r_ui=3.0, est=3.764346271636999, details={'was_impossible': False}),
#  Prediction(uid='416', iid='775', r_ui=4.0, est=3.1963192737949, details={'was_impossible': False}),
#  Prediction(uid='189', iid='28', r_ui=4.0, est=4.027465171618683, details={'was_impossible': False}),
#  Prediction(uid='927', iid='155', r_ui=4.0, est=3.537695345827203, details={'was_impossible': False}),
#  Prediction(uid='658', iid='257', r_ui=4.0, est=3.4844566048493735, details={'was_impossible': False}),
#  Prediction(uid='276', iid='540', r_ui=1.0, est=2.668300817297577, details={'was_impossible': False}),
#  Prediction(uid='675', iid='86', r_ui=4.0, est=4.001383922978546, details={'was_impossible': False}),
#  Prediction(uid='234', iid='842', r_ui=4.0, est=2.462672888297098, details={'was_impossible': False}),
#  Prediction(uid='665', iid='274', r_ui=3.0, est=3.4273453115736676, details={'was_impossible': False}),
#  Prediction(uid='201', iid='366', r_ui=2.0, est=2.647299371988218, details={'was_impossible': False}),
#  Prediction(uid='121', iid='257', r_ui=5.0, est=3.506163564134647, details={'was_impossible': False}),
#  Prediction(uid='409', iid='607', r_ui=5.0, est=3.7836625852270855, details={'was_impossible': False}),
#  Prediction(uid='417', iid='628', r_ui=3.0, est=3.325422758177258, details={'was_impossible': False}),
#  Prediction(uid='918', iid='529', r_ui=3.0, est=3.529965539565439, details={'was_impossible': False}),
#  Prediction(uid='85', iid='464', r_ui=5.0, est=3.243555095669695, details={'was_impossible': False}),
#  Prediction(uid='327', iid='239', r_ui=3.0, est=2.8311146578266015, details={'was_impossible': False}),
#  Prediction(uid='188', iid='118', r_ui=3.0, est=3.546561639457709, details={'was_impossible': False}),
#  Prediction(uid='506', iid='410', r_ui=2.0, est=3.8520876531993347, details={'was_impossible': False}),
#  Prediction(uid='709', iid='762', r_ui=3.0, est=3.2949162948808595, details={'was_impossible': False}),
#  Prediction(uid='507', iid='597', r_ui=5.0, est=4.351379454873196, details={'was_impossible': False}),
#  Prediction(uid='538', iid='191', r_ui=5.0, est=4.00523954535319, details={'was_impossible': False}),
#  Prediction(uid='773', iid='475', r_ui=3.0, est=3.780261805631427, details={'was_impossible': False}),
#  Prediction(uid='763', iid='730', r_ui=5.0, est=3.6802509644035033, details={'was_impossible': False}),
#  Prediction(uid='682', iid='1012', r_ui=4.0, est=3.313529635215271, details={'was_impossible': False}),
#  Prediction(uid='76', iid='1155', r_ui=2.0, est=3.5765745302107677, details={'was_impossible': False}),
#  Prediction(uid='481', iid='427', r_ui=4.0, est=4.832561868501236, details={'was_impossible': False}),
#  Prediction(uid='184', iid='396', r_ui=3.0, est=3.2324091075229697, details={'was_impossible': False}),
#  Prediction(uid='501', iid='1011', r_ui=4.0, est=3.5815283327680634, details={'was_impossible': False}),
#  Prediction(uid='84', iid='286', r_ui=5.0, est=3.3506406254954735, details={'was_impossible': False}),
#  Prediction(uid='897', iid='82', r_ui=5.0, est=4.389810044990515, details={'was_impossible': False}),
#  Prediction(uid='40', iid='245', r_ui=3.0, est=2.690218563414565, details={'was_impossible': False}),
#  Prediction(uid='690', iid='712', r_ui=4.0, est=2.7058701981356603, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1182', r_ui=3.0, est=3.009543897099624, details={'was_impossible': False}),
#  Prediction(uid='840', iid='7', r_ui=4.0, est=3.8480079228865565, details={'was_impossible': False}),
#  Prediction(uid='585', iid='166', r_ui=4.0, est=3.953249430803487, details={'was_impossible': False}),
#  Prediction(uid='648', iid='89', r_ui=4.0, est=3.6149625684763476, details={'was_impossible': False}),
#  Prediction(uid='102', iid='672', r_ui=1.0, est=2.093295437540786, details={'was_impossible': False}),
#  Prediction(uid='833', iid='159', r_ui=2.0, est=2.4875134501438585, details={'was_impossible': False}),
#  Prediction(uid='325', iid='430', r_ui=5.0, est=4.025727994408193, details={'was_impossible': False}),
#  Prediction(uid='787', iid='880', r_ui=3.0, est=3.3930058594720545, details={'was_impossible': False}),
#  Prediction(uid='357', iid='117', r_ui=5.0, est=4.661874393901704, details={'was_impossible': False}),
# ...
#  Prediction(uid='296', iid='286', r_ui=5.0, est=3.9069087464707826, details={'was_impossible': False}),
#  Prediction(uid='618', iid='382', r_ui=2.0, est=3.2173588476335255, details={'was_impossible': False}),
#  Prediction(uid='42', iid='173', r_ui=5.0, est=4.101489954516082, details={'was_impossible': False}),
#  Prediction(uid='561', iid='890', r_ui=1.0, est=1.5057442317570837, details={'was_impossible': False}),
#  Prediction(uid='14', iid='174', r_ui=5.0, est=4.611479432278026, details={'was_impossible': False}),
#  Prediction(uid='445', iid='313', r_ui=2.0, est=2.1539410584444703, details={'was_impossible': False}),
#  Prediction(uid='370', iid='265', r_ui=5.0, est=3.769467477762684, details={'was_impossible': False}),
#  Prediction(uid='379', iid='523', r_ui=4.0, est=4.2155695048906905, details={'was_impossible': False}),
#  Prediction(uid='823', iid='144', r_ui=5.0, est=4.100467375919685, details={'was_impossible': False}),
#  Prediction(uid='81', iid='25', r_ui=5.0, est=3.5256224313960485, details={'was_impossible': False}),
#  Prediction(uid='393', iid='153', r_ui=3.0, est=3.638639918956427, details={'was_impossible': False}),
#  Prediction(uid='160', iid='544', r_ui=4.0, est=3.660541797805427, details={'was_impossible': False}),
#  Prediction(uid='496', iid='56', r_ui=5.0, est=3.1861019715018433, details={'was_impossible': False}),
#  Prediction(uid='923', iid='148', r_ui=4.0, est=3.955573775352396, details={'was_impossible': False}),
#  Prediction(uid='363', iid='90', r_ui=5.0, est=2.721370327820588, details={'was_impossible': False}),
#  Prediction(uid='847', iid='39', r_ui=2.0, est=2.7184580688346207, details={'was_impossible': False}),
#  Prediction(uid='363', iid='87', r_ui=3.0, est=3.5412565481352014, details={'was_impossible': False}),
#  Prediction(uid='456', iid='1107', r_ui=4.0, est=2.7437466773813584, details={'was_impossible': False}),
#  Prediction(uid='497', iid='202', r_ui=4.0, est=3.4004484275447493, details={'was_impossible': False}),
#  Prediction(uid='943', iid='233', r_ui=5.0, est=3.2384818767937005, details={'was_impossible': False}),
#  Prediction(uid='65', iid='211', r_ui=4.0, est=4.149630795079222, details={'was_impossible': False}),
#  Prediction(uid='524', iid='1041', r_ui=2.0, est=2.907017412532877, details={'was_impossible': False}),
#  Prediction(uid='244', iid='1225', r_ui=2.0, est=3.346717811603619, details={'was_impossible': False}),
#  Prediction(uid='854', iid='423', r_ui=4.0, est=3.5198354341305174, details={'was_impossible': False}),
#  Prediction(uid='343', iid='77', r_ui=3.0, est=3.527800185090863, details={'was_impossible': False}),
#  Prediction(uid='313', iid='488', r_ui=5.0, est=4.096226923371558, details={'was_impossible': False}),
#  Prediction(uid='13', iid='540', r_ui=3.0, est=2.21995254561839, details={'was_impossible': False}),
#  Prediction(uid='911', iid='474', r_ui=5.0, est=4.285278727968673, details={'was_impossible': False}),
#  Prediction(uid='554', iid='209', r_ui=4.0, est=4.0292183494549105, details={'was_impossible': False}),
#  Prediction(uid='277', iid='129', r_ui=4.0, est=3.672270020458361, details={'was_impossible': False}),
#  Prediction(uid='908', iid='701', r_ui=4.0, est=3.41906674853216, details={'was_impossible': False}),
#  Prediction(uid='625', iid='519', r_ui=2.0, est=3.743091804593521, details={'was_impossible': False}),
#  Prediction(uid='712', iid='215', r_ui=3.0, est=4.5035524895472285, details={'was_impossible': False}),
#  Prediction(uid='181', iid='934', r_ui=3.0, est=1.2444343258497534, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1231', r_ui=2.0, est=2.5178737218913123, details={'was_impossible': False}),
#  Prediction(uid='324', iid='748', r_ui=5.0, est=4.263980968945813, details={'was_impossible': False}),
#  Prediction(uid='263', iid='1126', r_ui=5.0, est=3.365438696544005, details={'was_impossible': False}),
#  Prediction(uid='639', iid='70', r_ui=3.0, est=2.891967914043125, details={'was_impossible': False}),
#  Prediction(uid='398', iid='159', r_ui=3.0, est=3.3440817659019473, details={'was_impossible': False}),
#  Prediction(uid='286', iid='56', r_ui=2.0, est=3.5089927261813214, details={'was_impossible': False}),
#  Prediction(uid='486', iid='1302', r_ui=3.0, est=3.3913239989759845, details={'was_impossible': False}),
#  Prediction(uid='556', iid='187', r_ui=5.0, est=4.549204248501281, details={'was_impossible': False}),
#  Prediction(uid='280', iid='217', r_ui=3.0, est=3.7186220445347673, details={'was_impossible': False}),
#  Prediction(uid='807', iid='373', r_ui=4.0, est=3.4859925663441254, details={'was_impossible': False}),
#  Prediction(uid='883', iid='271', r_ui=2.0, est=3.269415262776432, details={'was_impossible': False}),
#  Prediction(uid='62', iid='147', r_ui=3.0, est=3.277921253779028, details={'was_impossible': False}),
#  Prediction(uid='523', iid='1036', r_ui=4.0, est=3.890337067727626, details={'was_impossible': False}),
#  Prediction(uid='748', iid='144', r_ui=4.0, est=3.5710935942314026, details={'was_impossible': False}),
#  Prediction(uid='927', iid='385', r_ui=4.0, est=3.8491494735835783, details={'was_impossible': False}),
#  Prediction(uid='50', iid='1008', r_ui=5.0, est=3.3992955643421396, details={'was_impossible': False}),
#  Prediction(uid='128', iid='485', r_ui=3.0, est=3.813266482871169, details={'was_impossible': False}),
#  Prediction(uid='299', iid='345', r_ui=4.0, est=3.096150201693581, details={'was_impossible': False}),
#  Prediction(uid='551', iid='1419', r_ui=1.0, est=2.7082918896929886, details={'was_impossible': False}),
#  Prediction(uid='144', iid='262', r_ui=3.0, est=3.720192204956262, details={'was_impossible': False}),
#  Prediction(uid='916', iid='483', r_ui=5.0, est=4.475478760087217, details={'was_impossible': False}),
#  Prediction(uid='189', iid='647', r_ui=4.0, est=4.337505484328035, details={'was_impossible': False}),
#  Prediction(uid='326', iid='657', r_ui=5.0, est=3.7206279729443987, details={'was_impossible': False}),
#  Prediction(uid='647', iid='1047', r_ui=4.0, est=3.0863137151719355, details={'was_impossible': False}),
#  Prediction(uid='406', iid='1197', r_ui=3.0, est=3.30365524536423, details={'was_impossible': False}),
#  Prediction(uid='533', iid='580', r_ui=3.0, est=3.042301809189464, details={'was_impossible': False}),
#  Prediction(uid='378', iid='265', r_ui=4.0, est=3.9262751122918003, details={'was_impossible': False}),
#  Prediction(uid='693', iid='1232', r_ui=2.0, est=2.2610454545346785, details={'was_impossible': False}),
#  Prediction(uid='327', iid='546', r_ui=2.0, est=2.499617804118838, details={'was_impossible': False}),
#  Prediction(uid='244', iid='258', r_ui=5.0, est=3.8454714663199914, details={'was_impossible': False}),
#  Prediction(uid='897', iid='176', r_ui=5.0, est=4.155190279704208, details={'was_impossible': False}),
#  Prediction(uid='269', iid='168', r_ui=4.0, est=3.8105384226821966, details={'was_impossible': False}),
#  Prediction(uid='821', iid='495', r_ui=5.0, est=4.165053390682917, details={'was_impossible': False}),
#  Prediction(uid='295', iid='50', r_ui=5.0, est=4.732185469376709, details={'was_impossible': False}),
#  Prediction(uid='904', iid='66', r_ui=4.0, est=4.059074063713931, details={'was_impossible': False}),
#  Prediction(uid='437', iid='378', r_ui=4.0, est=4.074708677220711, details={'was_impossible': False}),
#  Prediction(uid='751', iid='742', r_ui=3.0, est=3.5353176166847042, details={'was_impossible': False}),
#  Prediction(uid='442', iid='172', r_ui=5.0, est=4.010045776712441, details={'was_impossible': False}),
#  Prediction(uid='542', iid='772', r_ui=4.0, est=2.9870832167047836, details={'was_impossible': False}),
#  Prediction(uid='847', iid='567', r_ui=3.0, est=2.199080984451069, details={'was_impossible': False}),
#  Prediction(uid='44', iid='24', r_ui=3.0, est=3.5086593806993362, details={'was_impossible': False}),
#  Prediction(uid='425', iid='27', r_ui=3.0, est=2.572087725336213, details={'was_impossible': False}),
#  Prediction(uid='668', iid='333', r_ui=3.0, est=3.3971134075530838, details={'was_impossible': False}),
#  Prediction(uid='581', iid='222', r_ui=3.0, est=3.715460300028094, details={'was_impossible': False}),
#  Prediction(uid='666', iid='651', r_ui=5.0, est=3.9394736679176443, details={'was_impossible': False}),
#  Prediction(uid='593', iid='742', r_ui=4.0, est=3.994809940975218, details={'was_impossible': False}),
#  Prediction(uid='423', iid='1134', r_ui=4.0, est=3.511616910255525, details={'was_impossible': False}),
#  Prediction(uid='790', iid='72', r_ui=2.0, est=2.585376233225805, details={'was_impossible': False}),
#  Prediction(uid='896', iid='58', r_ui=3.0, est=3.350662449590267, details={'was_impossible': False}),
#  Prediction(uid='288', iid='528', r_ui=4.0, est=4.141774518604159, details={'was_impossible': False}),
#  Prediction(uid='14', iid='81', r_ui=5.0, est=3.899357664599225, details={'was_impossible': False}),
#  Prediction(uid='454', iid='493', r_ui=2.0, est=3.1466711482326826, details={'was_impossible': False}),
#  Prediction(uid='605', iid='252', r_ui=4.0, est=2.973024176345172, details={'was_impossible': False}),
#  Prediction(uid='468', iid='612', r_ui=4.0, est=4.260172868979232, details={'was_impossible': False}),
#  Prediction(uid='805', iid='99', r_ui=2.0, est=3.4274561998881055, details={'was_impossible': False}),
#  Prediction(uid='512', iid='183', r_ui=5.0, est=4.232699373639561, details={'was_impossible': False}),
#  Prediction(uid='33', iid='245', r_ui=3.0, est=3.303775627689629, details={'was_impossible': False}),
#  Prediction(uid='401', iid='151', r_ui=1.0, est=3.0511432225204738, details={'was_impossible': False}),
#  Prediction(uid='818', iid='271', r_ui=4.0, est=3.4517687889417283, details={'was_impossible': False}),
#  Prediction(uid='550', iid='300', r_ui=4.0, est=3.97068695797882, details={'was_impossible': False}),
#  Prediction(uid='270', iid='123', r_ui=5.0, est=4.005417965243286, details={'was_impossible': False}),
#  Prediction(uid='644', iid='117', r_ui=4.0, est=4.374561169260971, details={'was_impossible': False}),
#  Prediction(uid='453', iid='515', r_ui=4.0, est=4.183819350701293, details={'was_impossible': False}),
#  Prediction(uid='210', iid='180', r_ui=4.0, est=4.235115922858674, details={'was_impossible': False}),
#  Prediction(uid='247', iid='70', r_ui=5.0, est=3.6764132195133796, details={'was_impossible': False}),
#  Prediction(uid='500', iid='699', r_ui=3.0, est=3.940308476429947, details={'was_impossible': False}),
#  Prediction(uid='909', iid='261', r_ui=5.0, est=3.138164502389659, details={'was_impossible': False}),
#  Prediction(uid='595', iid='460', r_ui=4.0, est=2.8506052663320225, details={'was_impossible': False}),
#  Prediction(uid='804', iid='1285', r_ui=2.0, est=3.5426917516014935, details={'was_impossible': False}),
#  Prediction(uid='899', iid='403', r_ui=3.0, est=3.2294849240550882, details={'was_impossible': False}),
#  Prediction(uid='368', iid='670', r_ui=3.0, est=2.8258012120451546, details={'was_impossible': False}),
#  Prediction(uid='201', iid='226', r_ui=3.0, est=2.420720634692893, details={'was_impossible': False}),
#  Prediction(uid='606', iid='64', r_ui=5.0, est=4.679733727431554, details={'was_impossible': False}),
#  Prediction(uid='246', iid='121', r_ui=4.0, est=2.284609816019465, details={'was_impossible': False}),
#  Prediction(uid='145', iid='298', r_ui=1.0, est=4.073262897856449, details={'was_impossible': False}),
#  Prediction(uid='751', iid='746', r_ui=4.0, est=3.533542327703903, details={'was_impossible': False}),
#  Prediction(uid='280', iid='99', r_ui=2.0, est=3.9310600629869885, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1185', r_ui=3.0, est=2.3820624099294454, details={'was_impossible': False}),
#  Prediction(uid='861', iid='737', r_ui=3.0, est=3.3544160160997354, details={'was_impossible': False}),
#  Prediction(uid='593', iid='553', r_ui=2.0, est=3.3843933749931807, details={'was_impossible': False}),
#  Prediction(uid='487', iid='823', r_ui=1.0, est=2.86856769839429, details={'was_impossible': False}),
#  Prediction(uid='697', iid='596', r_ui=4.0, est=3.3541202674266968, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1470', r_ui=2.0, est=1.7411295809735077, details={'was_impossible': False}),
#  Prediction(uid='151', iid='49', r_ui=3.0, est=3.4100061657164518, details={'was_impossible': False}),
#  Prediction(uid='387', iid='972', r_ui=2.0, est=3.0443298230195777, details={'was_impossible': False}),
#  Prediction(uid='889', iid='199', r_ui=5.0, est=4.2087641016361195, details={'was_impossible': False}),
#  Prediction(uid='106', iid='956', r_ui=3.0, est=3.73506102683151, details={'was_impossible': False}),
#  Prediction(uid='495', iid='413', r_ui=5.0, est=3.16442671439192, details={'was_impossible': False}),
#  Prediction(uid='896', iid='184', r_ui=3.0, est=3.1442256216760205, details={'was_impossible': False}),
#  Prediction(uid='314', iid='1218', r_ui=4.0, est=4.302058138223167, details={'was_impossible': False}),
#  Prediction(uid='303', iid='1110', r_ui=1.0, est=2.8488008982225232, details={'was_impossible': False}),
#  Prediction(uid='551', iid='118', r_ui=5.0, est=2.4661840086315343, details={'was_impossible': False}),
#  Prediction(uid='495', iid='768', r_ui=3.0, est=3.5661438797950082, details={'was_impossible': False}),
#  Prediction(uid='624', iid='405', r_ui=4.0, est=3.587867557554836, details={'was_impossible': False}),
#  Prediction(uid='474', iid='275', r_ui=3.0, est=4.265312442959389, details={'was_impossible': False}),
#  Prediction(uid='417', iid='325', r_ui=2.0, est=2.1275654712380327, details={'was_impossible': False}),
#  Prediction(uid='654', iid='736', r_ui=5.0, est=3.6751769719906457, details={'was_impossible': False}),
#  Prediction(uid='336', iid='451', r_ui=2.0, est=3.1304241539078723, details={'was_impossible': False}),
#  Prediction(uid='417', iid='5', r_ui=4.0, est=3.3867802745841797, details={'was_impossible': False}),
#  Prediction(uid='399', iid='418', r_ui=3.0, est=2.953074483883458, details={'was_impossible': False}),
#  Prediction(uid='699', iid='304', r_ui=4.0, est=3.350612513533085, details={'was_impossible': False}),
#  Prediction(uid='26', iid='283', r_ui=3.0, est=3.280850444910693, details={'was_impossible': False}),
#  Prediction(uid='941', iid='358', r_ui=2.0, est=3.08866281358058, details={'was_impossible': False}),
#  Prediction(uid='653', iid='101', r_ui=3.0, est=2.487545679696372, details={'was_impossible': False}),
#  Prediction(uid='608', iid='136', r_ui=3.0, est=4.095570871896384, details={'was_impossible': False}),
#  Prediction(uid='710', iid='346', r_ui=4.0, est=3.7267380727848813, details={'was_impossible': False}),
#  Prediction(uid='390', iid='328', r_ui=4.0, est=3.376886257638714, details={'was_impossible': False}),
#  Prediction(uid='316', iid='735', r_ui=4.0, est=3.671123643291987, details={'was_impossible': False}),
#  Prediction(uid='796', iid='182', r_ui=4.0, est=3.728435247513123, details={'was_impossible': False}),
#  Prediction(uid='327', iid='678', r_ui=3.0, est=2.2233175767846096, details={'was_impossible': False}),
#  Prediction(uid='197', iid='11', r_ui=1.0, est=3.484726441838149, details={'was_impossible': False}),
#  Prediction(uid='275', iid='679', r_ui=3.0, est=2.7441515704521815, details={'was_impossible': False}),
#  Prediction(uid='102', iid='778', r_ui=3.0, est=2.729192250744619, details={'was_impossible': False}),
#  Prediction(uid='715', iid='53', r_ui=1.0, est=2.750405824424943, details={'was_impossible': False}),
#  Prediction(uid='334', iid='483', r_ui=5.0, est=4.298215547583957, details={'was_impossible': False}),
#  Prediction(uid='62', iid='196', r_ui=4.0, est=3.4454878053567017, details={'was_impossible': False}),
#  Prediction(uid='601', iid='699', r_ui=3.0, est=3.2546347112276397, details={'was_impossible': False}),
#  Prediction(uid='145', iid='595', r_ui=3.0, est=3.287952937932117, details={'was_impossible': False}),
#  Prediction(uid='250', iid='596', r_ui=5.0, est=3.7493665110624894, details={'was_impossible': False}),
#  ...]
# RMSE: 0.9434
# 0.9433567610472382
# movieId для данного пользователя: ['174', '427', '568', '234']

# %% [markdown]
# ### Юнит 5. Современные методы: глубокое обучение

# %%
print(tf.__version__)
# Out:
# 2.20.0

# %%
df = pd.read_csv('data/Gooddreadbooks/ratings.csv')
display(df.head())
display(df.info())
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981756 entries, 0 to 981755
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   book_id  981756 non-null  int64
#  1   user_id  981756 non-null  int64
#  2   rating   981756 non-null  int64
# dtypes: int64(3)
# memory usage: 22.5 MB
# None

# %%
#Задание 5.1

train, test = sklearn.model_selection.train_test_split(df, test_size=0.2, random_state=42)
print('Количество объектов в обучающей выборке:', train.shape[0])
# Out:
# Количество объектов в обучающей выборке: 785404

# %%
#Задание 5.2

n_books = df['book_id'].nunique()
print('Количество уникальных книг в данных:', n_books)
# Out:
# Количество уникальных книг в данных: 10000

# %%
#Задание 5.3

n_users = df['user_id'].nunique()
print('Количество уникальных пользователей в данных:', n_users)
# Out:
# Количество уникальных пользователей в данных: 53424

# %%
#Эмбеддинги и векторы для книг и пользователей

book_input = Input(shape=[1], name="Book-Input")
book_embedding = Embedding(n_books+1, 5, name="Book-Embedding")(book_input)
book_vec = Flatten(name="Flatten-Books")(book_embedding)

user_input = Input(shape=[1], name="User-Input")
user_embedding = Embedding(n_users+1, 5, name="User-Embedding")(user_input)
user_vec = Flatten(name="Flatten-Users")(user_embedding)

#Соединим векторы
conc = Concatenate()([book_vec, user_vec])

#Собираем нейросеть
fc1 = Dense(128, activation='relu')(conc)
fc2 = Dense(32, activation='relu')(fc1)
out = Dense(1)(fc2)

model2 = Model([user_input, book_input], out)

#Добавляем оптимизатор и метрику обучения
model2.compile(optimizer = 'adam', loss = 'mean_squared_error')

#Обучение модели
history = model2.fit([train.user_id, train.book_id], train.rating, epochs=5, verbose=1)

#Оценка качества
model2.evaluate([test.user_id, test.book_id], test.rating)
# Out:
# Epoch 1/5
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 0.8012
# Epoch 2/5
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 0.6872
# Epoch 3/5
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 41s 2ms/step - loss: 0.6570
# Epoch 4/5
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 0.6348
# Epoch 5/5
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 40s 2ms/step - loss: 0.6153
# 6136/6136 ━━━━━━━━━━━━━━━━━━━━ 5s 729us/step - loss: 0.7070
# 0.707029402256012

# %%
#Добавим ещё слой, больше эпох и обучим заново
fc1 = Dense(128, activation='relu')(conc)
fc2 = Dense(32, activation='relu')(fc1)
fc3 = Dense(8, activation='relu')(fc2)
out = Dense(1)(fc3)

model2 = Model([user_input, book_input], out)
model2.compile('adam', 'mean_squared_error')
result = model2.fit([train.user_id, train.book_id], train.rating, epochs=10, verbose=1)
model2.evaluate([test.user_id, test.book_id], test.rating)
# Out:
# Epoch 1/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 0.6262
# Epoch 2/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 39s 2ms/step - loss: 0.5820
# Epoch 3/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 46s 2ms/step - loss: 0.5611
# Epoch 4/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - loss: 0.5435
# Epoch 5/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - loss: 0.5289
# Epoch 6/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 36s 1ms/step - loss: 0.5170
# Epoch 7/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 44s 2ms/step - loss: 0.5065
# Epoch 8/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - loss: 0.4974
# Epoch 9/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - loss: 0.4895
# Epoch 10/10
# 24544/24544 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - loss: 0.4824
# 6136/6136 ━━━━━━━━━━━━━━━━━━━━ 5s 740us/step - loss: 0.7763
# 0.7763336896896362
