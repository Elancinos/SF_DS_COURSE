# %% [markdown]
# # <center> MATH&ML-13. Временные ряды. Часть II

# %% [markdown]
# ### Юнит 10. Другие методы предсказания временных рядов

# %% [markdown]
# Prophet

# %%
import pandas as pd

from prophet import Prophet

url = 'https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv'

df = pd.read_csv(url)

display(df.head())
df.shape
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572
# (2905, 2)

# %%
model = Prophet()
model.fit(df)

future_df = model.make_future_dataframe(periods=365)

future_df.shape
# Out:
# 13:21:26 - cmdstanpy - INFO - Chain [1] start processing
# 13:21:26 - cmdstanpy - INFO - Chain [1] done processing
# (3270, 1)

# %%
forecast_df = model.predict(future_df)
forecast_df[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.206966    7.431792    8.896677
# 3266 2017-01-16  8.531961    7.809313    9.215355
# 3267 2017-01-17  8.319378    7.618735    9.054754
# 3268 2017-01-18  8.151994    7.471338    8.934314
# 3269 2017-01-19  8.163910    7.486879    8.914424

# %%
#Отображение прогноза
fig = model.plot(forecast_df)

# %%
#Отображение компонент ряда
fig = model.plot_components(forecast_df)
