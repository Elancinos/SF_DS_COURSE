# %%
import numpy as np

import sympy
from sympy import Eq, solveset, Symbol, symbols, Interval, S, log, sin, cos, exp, diff, solve, N
# Аккуратный вывод формул
from sympy import init_printing

from sympy.calculus.util import function_range, continuous_domain

# %%
# Задание 2
v1 = np.array([2,10,-2]).T
v2 = np.array([3,2,-2]).T
v3 = np.array([8,14,-6]).T

np.linalg.matrix_rank([v1, v2, v3])
# Out:
# 2

# %%
#Задание 5
x = np.array([[14.3, 21.2, 8.34, 15.32],
              [4.3, 3.1, 0.36, 12.42],
              [18.6, 24.3, 8.7, 27.74]]).T
y = np.array([[133.18, 178.6, 56.7, 145.9]]).T

# np.linalg.inv(x.T@x)@x.T@y матрица вырождена

# %%
#Задание 11

x, y = symbols('x y')
func = (3 - 8*x - y)**2
display(func.diff(x))
display(func.diff(y))
display(solve([func.diff(x), func.diff(y)]))
# Out:
# 128*x + 16*y - 48
# 16*x + 2*y - 6
# {x: 3/8 - y/8}
